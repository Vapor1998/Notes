# %%
import pandas as pd
import numpy as np

terror = pd.read_csv('terrorismData.csv')
df = terror.copy()

a = df[df['State'] == 'Jammu and Kashmir']
city_list = a['City'].value_counts()
city = city_list.index[0]
attacks =city_list.values[0]
a  = df[df["City"] == city]
terrorist = a["Group"].value_counts().index[1]
print(city, attacks, terrorist)
# Out:
# Srinagar 657 Muslim Separatists

# %%
import pandas as pd
df = pd.read_csv('terrorismData.csv')
df = df[df['Country'] == 'India']
df = df[((df.Year == 2014) & (df.Month == 5) & (df.Day >= 26)) | ((df.Year == 2014) & (df.Month > 5)) | (df.Year > 2014)]
attacks = df.shape[0]
df = df[df['Group'] != 'Unknown']
group = df['Group'].value_counts().index[0]
#print(attacks, group)
# Out:
# 3336 Maoists

# %%
import pandas as pd
df=pd.read_csv("terrorismData.csv")
df=df[df.Country=="India"]
df=df[df["Year"]>2013]
df.head(20)
# Out:
#         Year  Month  Day Country              State      Region  \
# 125343  2014      1    1   India            Manipur  South Asia
# 125344  2014      1    1   India            Manipur  South Asia
# 125366  2014      1    1   India            Haryana  South Asia
# 125373  2014      1    1   India             Odisha  South Asia
# 125374  2014      1    1   India       Chhattisgarh  South Asia
# 125453  2014      1    3   India             Odisha  South Asia
# 125484  2014      1    4   India            Manipur  South Asia
# 125600  2014      1    6   India             Odisha  South Asia
# 125638  2014      1    7   India             Kerala  South Asia
# 125647  2014      1    7   India          Meghalaya  South Asia
# 125650  2014      1    7   India  Jammu and Kashmir  South Asia
# 125659  2014      1    7   India  Jammu and Kashmir  South Asia
# 125677  2014      1    8   India             Odisha  South Asia
# 125684  2014      1    7   India         Tamil Nadu  South Asia
# ...
