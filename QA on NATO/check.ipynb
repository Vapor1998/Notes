# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\HASHIM RAZI\Downloads\QuestionsGenerated8.csv")
# Out:
#                                                 Context  \
# 0      The Charter also established the NATO-Ukraine...
# 1     All NATO member countries and Ukraine are repr...
# 2     In May 2002, shortly before the fifth annivers...
# 3      The NATO-Ukraine Action PlanThe NATO-Ukraine ...
# 4      The NATO-Ukraine Action PlanThe NATO-Ukraine ...
# ...                                                 ...
# 1077  The NATO Standardization Agency (NSA) is a sin...
# 1078  The NSA supports Joint, Maritime, Land, Air an...
# 1079  The Director of the NSA is responsible for the...
# 1080  The Director of the NSA is responsible for the...
# 1081  The Director of the NSA is responsible for the...
#
#                                                Question  \
# 0            What is the NATO-Ukraine Commission (NUC)?
# 1     5. What is the highest level at which the NUC ...
# 2                  What was Ukraine's goal in May 2002?
# 3      What was adopted at the NUC meeting of foreig...
# 4      What is the purpose of the NATO-Ukraine Actio...
# ...                                                 ...
# 1077   Who is responsible for the coordination of is...
# 1078                        What does the NSA supports?
# 1079   Who is responsible for the day-to-day work of...
# 1080                   How many branches does NSA have?
# 1081   What are the responsibilities of the service ...
#
#                                                  Answer
# 0      The NATO-Ukraine Commission is the decision-m...
# 1                                                swers:
# 2        Ukraine's goal was to become a member of NATO.
# 3             The NATO-Ukraine Action Plan was adopted.
# 4      The purpose is to identify Ukraine's strategi...
# ...                                                 ...
# 1077   The NATO Standardization Agency (NSA) is resp...
# 1078   The NSA supports Joint, Maritime, Land, Air a...
# 1079   The Director of NSA is responsible for the da...
# 1080   The NSA has five branches, namely Policy and ...
# 1081   The service branches of NSA provide staff sup...
#
# [1082 rows x 3 columns]

# %%
df1 = pd.read_csv(r"C:\Users\HASHIM RAZI\Downloads\QuestionsGenerated7.csv")
df1
# Out:
#                                                Context  \
# 0     Anti-terrorist operations in the BalkansNATO ...
# 1     Anti-terrorist operations in the BalkansNATO ...
# 2     Anti-terrorist operations in the BalkansNATO ...
# 3     Military Concept for Defence against Terroris...
# 4     Military Concept for Defence against Terroris...
# ..                                                 ...
# 462   The evolution of relationsFormal relations be...
# 463   The evolution of relationsFormal relations be...
# 464  In Madrid on 9 July 1997, the Ukrainian presid...
# 465  In Madrid on 9 July 1997, the Ukrainian presid...
# 466  In Madrid on 9 July 1997, the Ukrainian presid...
#
#                                               Question  \
# 0     What has the contribution of NATO been in ant...
# 1     What was the main objective of NATO's operati...
# 2     How did NATO's operation in the Balkans contr...
# 3     What was approved at the November 2002 Prague...
# 4     Who will be targeted by the military concept ...
# ..                                                 ...
# 462   What was the first member state of the Common...
# 463   What did Ukraine demonstrate its commitment t...
# 464   What was the occasion for signing the Charter...
# 465                     What does the Charter provide?
# 466   What is the significance of the Charter accor...
#
#                                                 Answer
# 0     NATO-led forces have taken action against loc...
# 1     The main objective of NATO's operation in the...
# 2     NATO's operation in the Balkans contributed t...
# 3     A Military Concept for Defence against Terror...
# 4     The military concept will target terrorists a...
# ..                                                 ...
# 462                                            Ukraine
# 463   Contributing to Euro-Atlantic security throug...
# 464   The signing of the Charter took place in Madr...
# 465   It provides the formal basis for NATO-Ukraine...
# 466   The Alliance regards these factors as key to ...
#
# [467 rows x 3 columns]

# %%
df2 = pd.read_csv(r"C:\Users\HASHIM RAZI\Downloads\QuestionsGenerated6.csv")
df3 = pd.read_csv(r"C:\Users\HASHIM RAZI\Downloads\QuestionsGenerated5.csv")
df4 = pd.read_csv(r"C:\Users\HASHIM RAZI\Downloads\QuestionsGenerated4.csv")
df5 = pd.read_csv(r"C:\Users\HASHIM RAZI\Downloads\QuestionsGenerated3.csv")
df6 = pd.read_csv(r"C:\Users\HASHIM RAZI\Downloads\QuestionsGenerated2.csv")
df7 = pd.read_csv(r"C:\Users\HASHIM RAZI\Downloads\QuestionsGenerated1.csv")

# %%
df_concatenated = pd.concat([df, df1, df2, df3, df4, df5, df6, df7], ignore_index=True)

# %%
# Out:
#                                                 Context  \
# 0      Anti-terrorist operations in the BalkansNATO ...
# 1      Anti-terrorist operations in the BalkansNATO ...
# 2      Anti-terrorist operations in the BalkansNATO ...
# 3      Military Concept for Defence against Terroris...
# 4      Military Concept for Defence against Terroris...
# ...                                                 ...
# 2826   The Military Committee and most of the Commit...
# 2827   The Military Committee and most of the Commit...
# 2828   The Military Committee and most of the Commit...
# 2829   The Military Committee and most of the Commit...
# 2830   The Military Committee and most of the Commit...
#
#                                                Question  \
# 0      What has the contribution of NATO been in ant...
# 1      What was the main objective of NATO's operati...
# 2      How did NATO's operation in the Balkans contr...
# 3      What was approved at the November 2002 Prague...
# 4      Who will be targeted by the military concept ...
# ...                                                 ...
# 2826  2. Who meet regularly with representatives of ...
# 2827              3. Which Committees are listed below?
# 2828                       1. What does EAPC stand for?
# 2829   2. Who meet regularly with representatives of...
# 2830              3. Which Committees are listed below?
#
#                                                  Answer
# 0      NATO-led forces have taken action against loc...
# 1      The main objective of NATO's operation in the...
# 2      NATO's operation in the Balkans contributed t...
# 3      A Military Concept for Defence against Terror...
# 4      The military concept will target terrorists a...
# ...                                                 ...
# 2826   The Military Committee and most of the Commit...
# 2827     Military Committee and most of the Committees.
# 2828             The Euro-Atlantic Partnership Council.
# 2829   The Military Committee and most of the Commit...
# 2830   The Military Committee and most of the Commit...
#
# [2831 rows x 3 columns]
