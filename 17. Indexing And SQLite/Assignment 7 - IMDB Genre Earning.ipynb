# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

db = sqlite3.connect('IMDB.sqlite')

imdb = pd.read_sql_query('select * from IMDB', db)
earning = pd.read_sql_query('select * from earning', db)
genre = pd.read_sql_query('select * from genre', db)

df = earning.copy()
df['Total Earning'] = df['Domestic'] + df['Worldwide']

df1 = pd.merge(df, imdb, on = 'Movie_id', how = 'inner')
df2 = pd.merge(df1, genre, on = 'Movie_id', how = 'inner')
df2['genre'].replace('', np.nan, inplace = True)
df2['genre'].dropna()

a = df2['genre'].value_counts().index

arr = []
for i in a:
    b= df2.loc[df2['genre'] == i]
    q = b['Total Earning']
    q = np.array(q, dtype = np.int64)
    c = q.sum()
    arr.append(c)
    
for i in range(len(arr)):
    per = arr[i] / sum(arr) * 100
    print(a[i], format(per, '.2f'))
    
plt.pie(arr)
plt.show()
# Out:
# Drama 11.96
# Adventure 23.57
# Action 17.91
# Comedy 7.69
# Biography 3.42
# Sci-Fi 9.95
# Thriller 4.42
# Animation 6.77
# Romance 1.45
# Crime 1.55
# Mystery 2.01
# Fantasy 5.15
# History 1.04
# Family 1.05
# Music 0.43
# Sport 0.32
# War 0.25
# Horror 0.01
# Western 0.65
# Musical 0.38

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

db = sqlite3.connect('IMDB.sqlite')

imdb = pd.read_sql_query('select * from IMDB', db)
earning = pd.read_sql_query('select * from earning', db)
genre = pd.read_sql_query('select * from genre', db)

df = earning.copy()
df['Total Earning'] = df['Domestic'] + df['Worldwide']

df1 = pd.merge(df, imdb, on = 'Movie_id', how = 'inner')
df2 = pd.merge(df1, genre, on = 'Movie_id', how = 'inner')

df2['genre'].replace('', np.nan, inplace = True)   ## Concept on how to drop nan value if it does not drop.
                                                   ## Reason is dropna() does not drop empty string, so we convert 
                                                   ## empty string to np.nan and then drop the nan value. This works
df2['genre'].dropna()
a = df2['genre'].value_counts().index
# Out:
# Drama
# Adventure
# Action
# Comedy
# Biography
# Sci-Fi
# Thriller
# Animation
# Romance
# Crime
# Mystery
# Fantasy
# History
# Family
# Music
# Sport
# War
# Horror
# Western
# Musical

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

db = sqlite3.connect('IMDB.sqlite')

imdb = pd.read_sql_query('select * from IMDB', db)
earning = pd.read_sql_query('select * from earning', db)
genre = pd.read_sql_query('select * from genre', db)

df = earning.copy()
df['Total Earning'] = df['Domestic'] + df['Worldwide']

df1 = pd.merge(df, imdb, on = 'Movie_id', how = 'inner')
df2 = pd.merge(df1, genre, on = 'Movie_id', how = 'inner')
df2['genre'].replace('', np.nan, inplace = True)
df2['genre'].dropna()

a = df2['genre'].value_counts().index

# %%
df2
# Out:
#     Movie_id   Domestic     Worldwide  Total Earning  \
# 0      36809   56671993  1.877332e+08   2.444052e+08
# 1      36809   56671993  1.877332e+08   2.444052e+08
# 2      36809   56671993  1.877332e+08   2.444052e+08
# 3      30114   18335230  6.073880e+07   7.907403e+07
# 4      30114   18335230  6.073880e+07   7.907403e+07
# ..       ...        ...           ...            ...
# 346    42294  146408305  3.536241e+08   5.000324e+08
# 347    42294  146408305  3.536241e+08   5.000324e+08
# 348    32217  341268248  1.023784e+09   1.365052e+09
# 349    32217  341268248  1.023784e+09   1.365052e+09
# 350    32217  341268248  1.023784e+09   1.365052e+09
#
#                          Title  Rating  TotalVotes MetaCritic   Budget  \
# 0      12 Years a Slave (2013)     8.1      496092         96    2e+07
# 1      12 Years a Slave (2013)     8.1      496092         96    2e+07
# 2      12 Years a Slave (2013)     8.1      496092         96    2e+07
# 3             127 Hours (2010)     7.6      297075         82  1.8e+07
# 4             127 Hours (2010)     7.6      297075         82  1.8e+07
# ..                         ...     ...         ...        ...      ...
# 346  X-Men: First Class (2011)     7.8      556713         65  1.6e+08
# 347  X-Men: First Class (2011)     7.8      556713         65  1.6e+08
# 348            Zootopia (2016)     8.1      309474         78  1.5e+08
# 349            Zootopia (2016)     8.1      309474         78  1.5e+08
# 350            Zootopia (2016)     8.1      309474         78  1.5e+08
#
#      Runtime  ... Votes3044M Votes3044F Votes45A Votes45AM Votes45AF  \
# 0    134 min  ...        7.9        8.0      7.8       7.8       8.1
# 1    134 min  ...        7.9        8.0      7.8       7.8       8.1
# 2    134 min  ...        7.9        8.0      7.8       7.8       8.1
# 3     94 min  ...        7.5        7.5      7.3       7.3       7.5
# 4     94 min  ...        7.5        7.5      7.3       7.3       7.5
# ..       ...  ...        ...        ...      ...       ...       ...
# 346  132 min  ...        7.6        7.8      7.6       7.5       7.7
# 347  132 min  ...        7.6        7.8      7.6       7.5       7.7
# 348  108 min  ...        7.8        8.1      7.8       7.8       8.1
# 349  108 min  ...        7.8        8.1      7.8       7.8       8.1
# 350  108 min  ...        7.8        8.1      7.8       7.8       8.1
#
#     VotesIMDB Votes1000 VotesUS VotesnUS      genre
# 0         8.0       7.7     8.3      8.0  Biography
# 1         8.0       7.7     8.3      8.0      Drama
# 2         8.0       7.7     8.3      8.0    History
# 3         7.6       7.0     7.7      7.6  Adventure
# 4         7.6       7.0     7.7      7.6  Biography
# ..        ...       ...     ...      ...        ...
# 346       7.6       7.3     7.8      7.7  Adventure
# 347       7.6       7.3     7.8      7.7     Sci-Fi
# 348       7.7       7.6     8.0      8.0  Animation
# 349       7.7       7.6     8.0      8.0  Adventure
# 350       7.7       7.6     8.0      8.0     Comedy
#
# [351 rows x 56 columns]

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3
db = sqlite3.connect('IMDB.sqlite')
cur = db.cursor()
data = pd.read_sql_query('select * from earning',db)
data['total'] = data['Domestic'] + data['Worldwide']
data.to_sql('earning',db,if_exists = 'replace')
cur.execute('select distinct genre,sum(total) from genre join earning on genre.movie_id = earning.movie_id group by genre')
