# %%
dataset = {"The North Atlantic Treaty Organisation is an alliance of 26 countries from North America and Europe committed to fulfilling the goals of the North Atlantic Treaty signed in Washington on 4 April 1949.In accordance with the Treaty, the fundamental role of NATO is to safe guard the freedom and security of its member countries by political and military means. NATO safeguards the Allies’ common values of democracy, individual liberty, the rule of law and the peaceful resolution of disputes and promotes these values throughout the Euro-Atlantic area. It provides a forum in which countries from North America and Europe can consult together on security issues of common concern and take joint action in addressing them." :  [
    {
        "question": "What is NATO?",
        "answer": "NATO stands for the North Atlantic Treaty Organisation, which is an alliance of 26 countries from North America and Europe committed to fulfilling the goals of the North Atlantic Treaty signed in 1949."
    },
    {
        "question": "When was the North Atlantic Treaty signed?",
        "answer": "The North Atlantic Treaty was signed on 4 April 1949 in Washington."
    },
    {
        "question": "What is the fundamental role of NATO according to the Treaty?",
        "answer": "According to the Treaty, the fundamental role of NATO is to safeguard the freedom and security of its member countries by political and military means."
    },
    {
        "question": "What values does NATO safeguard?",
        "answer": "NATO safeguards the Allies' common values of democracy, individual liberty, the rule of law, and the peaceful resolution of disputes, and promotes these values throughout the Euro-Atlantic area."
    },
    {
        "question": "What is the purpose of NATO in addressing security issues?",
        "answer": "NATO provides a forum in which countries from North America and Europe can consult together on security issues of common concern and take joint action in addressing them."
    },
    {
        "question": "How many countries are part of NATO?",
        "answer": "NATO is an alliance of 26 countries from North America and Europe."
    },
    {
        "question": "What are the common values that NATO safeguards?",
        "answer": "NATO safeguards the common values of democracy, individual liberty, the rule of law, and the peaceful resolution of disputes."
    },
    {
        "question": "What is the goal of NATO according to the North Atlantic Treaty?",
        "answer": "The goal of NATO, according to the North Atlantic Treaty, is to safeguard the freedom and security of its member countries."
    },
    {
        "question": "What is the role of NATO in addressing security issues?",
        "answer": "NATO provides a platform for countries from North America and Europe to consult together on security issues of common concern and take joint action to address them."
    },
    {
        "question": "Where was the North Atlantic Treaty signed?",
        "answer": "The North Atlantic Treaty was signed in Washington on 4 April 1949."
    }
    
    
],
    "Relations between North American and European members of the Alliance are the bedrock of NATO. These countries share the same essential values and interests and are committed to the maintenance of democratic principles, making the security of Europe and that of North America indivisible. The Alliance is committed to defending its member states against aggression or the threat of aggression and to the principle that an attack against one or several members would be considered as an attack against all. NATO remains an inter-governmental organisation in which each member country retains its sovereignty. All NATO decisions are taken jointly by the member countries on the basis of consensus. NATO’s most important decisionmaking body is the North Atlantic Council, which brings together representatives of all the Allies at the level of ambassadors, ministers or heads of state and government. Each member country participates fully in the decisionmaking process on the basis of equality, irrespective of its size or political, military and economic strength."  : [
    {
        "question": "What is the bedrock of NATO?",
        "answer": "The bedrock of NATO is the relations between North American and European members of the Alliance."
    },
    {
        "question": "Why is the security of Europe and North America considered indivisible?",
        "answer": "The security of Europe and North America is considered indivisible because these countries share the same essential values and interests, and they are committed to the maintenance of democratic principles."
    },
    {
        "question": "What is NATO committed to defending its member states against?",
        "answer": "NATO is committed to defending its member states against aggression or the threat of aggression."
    },
    {
        "question": "What principle does NATO uphold regarding an attack on its members?",
        "answer": "NATO upholds the principle that an attack against one or several members would be considered as an attack against all."
    },
    {
        "question": "How are NATO decisions made?",
        "answer": "All NATO decisions are taken jointly by the member countries on the basis of consensus."
    },
    {
        "question": "What is the most important decision-making body in NATO?",
        "answer": "NATO's most important decision-making body is the North Atlantic Council, which brings together representatives of all the Allies at the level of ambassadors, ministers, or heads of state and government."
    },
    {
        "question": "How does each member country participate in the decision-making process in NATO?",
        "answer": "Each member country participates fully in the decision-making process on the basis of equality, irrespective of its size or political, military, and economic strength."
    }, 
        {
        "question": "What is the significance of the relations between North American and European members in NATO?",
        "answer": "The relations between North American and European members are considered the bedrock of NATO and are significant for the alliance."
    },
    {
        "question": "What is the role of the North Atlantic Council in NATO?",
        "answer": "The North Atlantic Council is NATO's most important decision-making body, bringing together representatives of all the Allies at various levels. It plays a crucial role in the alliance."
    },
    {
        "question": "How does NATO ensure that each member country has an equal say in decision-making?",
        "answer": "NATO ensures that each member country participates fully in the decision-making process on the basis of equality, regardless of its size or political, military, and economic strength."
    },
    {
        "question": "What is the core commitment of NATO when it comes to the defense of its member states?",
        "answer": "NATO is committed to defending its member states against aggression or the threat of aggression."
    },
    {
        "question": "What is the fundamental principle regarding attacks on NATO members?",
        "answer": "The fundamental principle is that an attack against one or several NATO members is considered as an attack against all, and the alliance will respond accordingly."
    }
],
  "The Allies therefore retain scope for independent action with respect to joint decisions and joint actions. However, Allied decisions, once taken, enable unified and concerted action to be reinforced by political solidarity. This was manifest, for example, in the decisions taken to provide assistance to the United States after the attacks of 11 September 2001. For the first time in its history, NATO invoked Article 5 of the Washington Treaty, which stipulates that an armedattack against one or more members of the Alliance is considered as anarmed attack against all. All the members of the Alliance vehemently condemned the attacks and provided support to the United States in its response." : [
    {
        "question": "Do the Allies in NATO have the ability to take independent action?",
        "answer": "Yes, the Allies in NATO retain scope for independent action with respect to joint decisions and joint actions."
    },
    {
        "question": "What happens once Allied decisions are taken in NATO?",
        "answer": "Once Allied decisions are taken, they enable unified and concerted action to be reinforced by political solidarity."
    },
    {
        "question": "Can you provide an example of political solidarity in NATO?",
        "answer": "One example of political solidarity in NATO is the decisions taken to provide assistance to the United States after the attacks of 11 September 2001."
    },
    {
        "question": "What is Article 5 of the Washington Treaty in NATO?",
        "answer": "Article 5 of the Washington Treaty stipulates that an armed attack against one or more members of the Alliance is considered as an armed attack against all."
    },
    {
        "question": "When was Article 5 of the Washington Treaty invoked in NATO?",
        "answer": "Article 5 of the Washington Treaty was invoked for the first time in NATO's history after the attacks of 11 September 2001."
    },
    {
        "question": "How did NATO member countries respond to the attacks of 11 September 2001?",
        "answer": "All the members of the Alliance vehemently condemned the attacks and provided support to the United States in its response."
    },
      
     {
        "question": "What is the significance of Allied decisions in NATO?",
        "answer": "Allied decisions in NATO enable unified and concerted action, which can be reinforced by political solidarity."
    },
    {
        "question": "Can NATO member countries take independent actions despite joint decisions?",
        "answer": "Yes, NATO member countries retain the scope for independent action even after joint decisions are made."
    },
    {
        "question": "When was Article 5 of the Washington Treaty invoked for the first time in NATO?",
        "answer": "Article 5 of the Washington Treaty was invoked for the first time in NATO's history after the 9/11 attacks on 11 September 2001."
    },
    {
        "question": "What is the significance of Article 5 of the Washington Treaty in NATO?",
        "answer": "Article 5 stipulates that an armed attack against one or more members of the Alliance is considered an attack against all, and it is a critical provision in NATO's defense strategy."
    },
    {
        "question": "How did NATO member countries respond to the 9/11 attacks in terms of Article 5?",
        "answer": "All NATO member countries invoked Article 5, condemning the attacks and offering support to the United States."
    } 
      
      
], 
  "NATO has no operational forces of its own other than those assigned to it by member countries or contributed by Partner countries for the purpose of carrying out a specific mission. It has a number of mechanisms available to it for this purpose – the defence planning and resource planning processes that form the basis of cooperation within the Alliance, the implementation of political commitments to improved capabilities, and a military structure that combines the functions of a multinational force planning organisation with an Alliance-wide system of command and control of the military forces assigned to it. In other words, under the command of NATO’s strategic commanders,the Organisation provides for the joint planning, exercising and operational deployment of forces provided by the member countries in accordance with a commonly agreed force planning process. In sum, an important part of NATO’s role is to act as a catalyst for generating the forces needed to meet requirements and enabling member countries to participate in crisis management operations which they could not otherwise undertake on their own.": [
    {
        "question": "Does NATO have its own operational forces?",
        "answer": "NATO does not have operational forces of its own, except for those assigned by member countries or contributed by Partner countries for specific missions."
    },
    {
        "question": "What mechanisms does NATO have for carrying out specific missions?",
        "answer": "NATO has several mechanisms, including defense planning, resource planning, and political commitments to improved capabilities. It also has a military structure that combines the functions of a multinational force planning organization with an Alliance-wide system of command and control."
    },
    {
        "question": "What is the role of NATO's strategic commanders?",
        "answer": "Under the command of NATO's strategic commanders, the organization provides for the joint planning, exercising, and operational deployment of forces provided by member countries in accordance with a commonly agreed force planning process."
    },
    {
        "question": "How does NATO enable member countries to participate in crisis management operations?",
        "answer": "NATO acts as a catalyst for generating the forces needed to meet requirements and enables member countries to participate in crisis management operations they could not otherwise undertake on their own."
    },
    {
        "question": "What are the key components of NATO's military structure?",
        "answer": "NATO's military structure combines the functions of a multinational force planning organization with an Alliance-wide system of command and control of the military forces assigned to it."
    },
      {
        "question": "How does NATO acquire operational forces for its missions?",
        "answer": "NATO acquires operational forces either from member countries or through contributions from Partner countries for specific missions."
    },
    {
        "question": "What is the role of NATO's defense planning and resource planning processes?",
        "answer": "The defense planning and resource planning processes in NATO form the basis of cooperation within the Alliance and contribute to the organization's ability to carry out specific missions."
    },
    {
        "question": "What is the function of NATO's military structure?",
        "answer": "NATO's military structure serves as a combination of a multinational force planning organization and an Alliance-wide system for command and control of assigned military forces."
    },
    {
        "question": "Who provides the forces for joint planning, exercising, and operational deployment in NATO?",
        "answer": "The member countries provide the forces for joint planning, exercising, and operational deployment under the command of NATO's strategic commanders."
    },
    {
        "question": "What is one of NATO's significant roles according to the provided text?",
        "answer": "One of NATO's significant roles is to act as a catalyst for generating the forces needed to meet requirements and enabling member countries to participate in crisis management operations that they couldn't undertake on their own."
    }
],
"Dialogue and cooperation with non-NATO countries have helped to overcome the divisions of the Cold War era and to extend security and stability well beyond NATO’s borders. The Alliance is deepening and broadening its cooperation with Russia and Ukraine and with other Partner countries – some of which have since become members – as well as with countries in the Mediterranean Dialogue programme and in the broader Middle East. It is also reinforcing cooperation with other international organisations and, in particular, with the European Union, with which it is developing a strategic partnership. NATO’s structures and mechanisms provide the framework for these varying forms of cooperation, which are an integral part of the day-to-day activity of the Alliance." : [
    {
        "question": "What has dialogue and cooperation with non-NATO countries helped to overcome?",
        "answer": "Dialogue and cooperation with non-NATO countries have helped to overcome the divisions of the Cold War era."
    },
    {
        "question": "How has NATO extended security and stability beyond its borders?",
        "answer": "NATO has extended security and stability well beyond its borders by deepening and broadening its cooperation with Russia, Ukraine, and other Partner countries, as well as with countries in the Mediterranean Dialogue program and the broader Middle East."
    },
    {
        "question": "With which international organization is NATO reinforcing its cooperation, according to the text?",
        "answer": "NATO is reinforcing cooperation with the European Union and developing a strategic partnership with it."
    },
    {
        "question": "What provides the framework for NATO's various forms of cooperation with other countries and international organizations?",
        "answer": "NATO's structures and mechanisms provide the framework for its various forms of cooperation, which are an integral part of the day-to-day activity of the Alliance."
    },
    {
        "question": "What is the significance of NATO's cooperation with non-NATO countries, according to the text?",
        "answer": "Cooperation with non-NATO countries is significant for extending security and stability beyond NATO's borders and overcoming Cold War-era divisions."
    },
    {
        "question": "What is the role of dialogue and cooperation with non-NATO countries?",
        "answer": "The role of dialogue and cooperation with non-NATO countries is to extend security and stability well beyond NATO's borders and overcome Cold War-era divisions."
    },
    {
        "question": "Which regions and countries does NATO cooperate with?",
        "answer": "NATO cooperates with Russia, Ukraine, other Partner countries, countries in the Mediterranean Dialogue program, the broader Middle East, and is reinforcing cooperation with the European Union."
    },
    {
        "question": "What kind of partnership is NATO developing with the European Union?",
        "answer": "NATO is developing a strategic partnership with the European Union."
    },
    {
        "question": "What provides the framework for NATO's cooperation with other countries and international organizations?",
        "answer": "NATO's structures and mechanisms provide the framework for its various forms of cooperation, which are integrated into the day-to-day activities of the Alliance."
    },
    {
        "question": "Why is NATO's cooperation with non-NATO countries important?",
        "answer": "NATO's cooperation with non-NATO countries is important for extending security and stability beyond the organization's borders and for addressing Cold War-era divisions."
    }
],
  "The origins of the Alliance From 1945 to 1949, faced with the pressing need for economic reconstruction, Western European countries and their North American allies viewed with concern the expansionist policies and methods of the USSR. Having fulfilled their own post-war undertakings to reduce their defence establishments and demobilise their forces, Western governments grew increasingly alarmed as it became clear that the Soviet leadership intended to maintain its own military forces at full strength. Moreover, in view of the declared ideological aims of the Soviet Communist Party, it was evident that appeals for respect for the United Nations Charter, and for respect for the international settlements reached at the end of the Second World War, would not guarantee the national sovereignty or independence of democratic states faced with the threat ofoutside aggression or internal subversion. The imposition of undemocratic forms of government and the repression of effective opposition and basic human and civil rights and freedoms in many Central and Eastern European countries, as well as elsewhere in the world, compounded these fears." :  [
    {
        "question": "What were the concerns of Western European countries and their North American allies in the post-World War II period?",
        "answer": "Western European countries and their North American allies were concerned about the expansionist policies and methods of the USSR and the Soviet leadership's intention to maintain a full-strength military."
    },
    {
        "question": "Why did Western governments grow increasingly alarmed during this period?",
        "answer": "Western governments grew increasingly alarmed because it became clear that the Soviet leadership intended to maintain its military forces at full strength, which raised concerns about national sovereignty and independence of democratic states."
    },
    {
        "question": "What was the impact of the declared ideological aims of the Soviet Communist Party?",
        "answer": "The declared ideological aims of the Soviet Communist Party raised concerns about the ability to guarantee national sovereignty and independence of democratic states faced with the threat of outside aggression or internal subversion."
    },
    {
        "question": "What were some of the actions that compounded these fears?",
        "answer": "The imposition of undemocratic forms of government, the repression of effective opposition, and the violation of basic human and civil rights and freedoms in Central and Eastern European countries, as well as elsewhere in the world, compounded these fears."
    },
    {
        "question": "What was the period between 1945 and 1949 characterized by in terms of the USSR's actions and the concerns of Western countries?",
        "answer": "The period between 1945 and 1949 was characterized by concerns in Western countries regarding the expansionist policies and methods of the USSR and the Soviet leadership's maintenance of a strong military."
    }, 
      {
        "question": "What were the post-World War II undertakings of Western governments?",
        "answer": "Western governments had undertaken to reduce their defense establishments and demobilize their forces after World War II."
    },
    {
        "question": "What were some of the reasons for Western governments' concerns about the USSR?",
        "answer": "Western governments were concerned about the expansionist policies of the USSR, the Soviet leadership's maintenance of a strong military, and the ideological aims of the Soviet Communist Party."
    },
    {
        "question": "Why did appeals for respect for the United Nations Charter and international settlements not guarantee national sovereignty and independence?",
        "answer": "Appeals for respect for the United Nations Charter and international settlements were not sufficient because they could not ensure the national sovereignty and independence of democratic states facing the threat of outside aggression or internal subversion."
    },
    {
        "question": "What actions by the Soviet leadership raised concerns among Western governments?",
        "answer": "The Soviet leadership's intention to maintain its military forces at full strength and the imposition of undemocratic forms of government, repression of opposition, and violations of human and civil rights and freedoms in various countries raised concerns."
    },
    {
        "question": "What led to the formation of the Alliance described in the text?",
        "answer": "The concerns and motivations arising from the actions and intentions of the USSR and the perceived threats to national sovereignty and independence led to the formation of the Alliance."
    }
], 
           "Between 1947 and 1949 a series of dramatic political events brought matters to a head. These included direct threats to the sovereignty of Norway, Greece, Turkey and other Western European countries, the June 1948 coup in Czechoslovakia, and the illegal blockade of Berlin which began in April of the same year. The signature of the Brussels Treaty in March 1948 marked the determination of five Western European countries – Belgium, France, Luxembourg, the Netherlands and the United Kingdom – to develop a common defence system and to strengthen the ties between them in a manner which would enable them to resist ideological, political and military threats to their security. The Brussels Treaty represented the first step in the post-war reconstruction of western european security and brought the Western Union Defence Organisation into being. It was also the first step in the process leading to the signature of the North Atlantic Treaty in 1949 and the creation of the North Atlantic Alliance. " : [
    {
        "question": "What were some of the dramatic political events between 1947 and 1949 that led to the formation of the Alliance?",
        "answer": "Some of the dramatic political events included direct threats to the sovereignty of Norway, Greece, Turkey, and other Western European countries, the June 1948 coup in Czechoslovakia, and the illegal blockade of Berlin that began in April of the same year."
    },
    {
        "question": "What was the significance of the Brussels Treaty signed in March 1948?",
        "answer": "The Brussels Treaty marked the determination of five Western European countries (Belgium, France, Luxembourg, the Netherlands, and the United Kingdom) to develop a common defense system and strengthen ties to resist ideological, political, and military threats to their security. It represented the first step in the post-war reconstruction of Western European security."
    },
    {
        "question": "What organization was brought into being by the Brussels Treaty?",
        "answer": "The Brussels Treaty brought the Western Union Defence Organisation into being."
    },
    {
        "question": "How does the text connect the Brussels Treaty to the creation of the North Atlantic Alliance?",
        "answer": "The Brussels Treaty was the first step in the process leading to the signature of the North Atlantic Treaty in 1949 and the creation of the North Atlantic Alliance."
    },
    {
        "question": "What did the Western European countries intend to achieve through the Brussels Treaty?",
        "answer": "The Western European countries intended to develop a common defense system and strengthen their ties to resist ideological, political, and military threats to their security."
    }, 
               {
        "question": "What were the direct threats to the sovereignty of specific countries mentioned in the text?",
        "answer": "The text mentions direct threats to the sovereignty of Norway, Greece, Turkey, and other Western European countries."
    },
    {
        "question": "What was the first step in the post-war reconstruction of Western European security?",
        "answer": "The first step in the post-war reconstruction of Western European security was the signing of the Brussels Treaty."
    },
    {
        "question": "What was the purpose of the Western Union Defence Organization brought into being by the Brussels Treaty?",
        "answer": "The Western Union Defence Organization was created to strengthen the defense capabilities and cooperation of Western European countries."
    },
    {
        "question": "What treaty and alliance were created as a result of the Brussels Treaty?",
        "answer": "The Brussels Treaty was the first step leading to the creation of the North Atlantic Treaty in 1949 and the North Atlantic Alliance."
    },
    {
        "question": "What motivated the Western European countries to strengthen their ties through the Brussels Treaty?",
        "answer": "The determination to resist ideological, political, and military threats to their security motivated Western European countries to strengthen their ties through the Brussels Treaty."
    }
], 
           "Negotiations with the United States and Canada then followed on the creation of a single North Atlantic Alliance based on security guarantees and mutual commitments between Europe and North America. Denmark, Iceland, Italy, Norway and Portugal were invited by the Brussels Treaty powers to become participants in this process. These negotiations culminated in the signatureof the Washington Treaty in April 1949, which introduced a common security system based on a partnership among these 12 countries. In 1952, Greece and Turkey acceded to the treaty. The Federal Republic of Germany joined the Alliance in 1955 and, in 1982, Spain also became a member of NATO. In 1990, with the unification of Germany, the former German Democratic Republic came under the security protection of the Alliance as an integral part of the united country. The Czech Republic, Hungary and Poland joined NATO in 1999. In 2003 seven more countries (Bulgaria, Estonia, Latvia, Lithuania, Romania, Slovakia and Slovenia) were invited to begin accession talks and formally acceded to the treaty in March 2004." : [
    {
        "question": "What was the goal of negotiations with the United States and Canada mentioned in the text?",
        "answer": "The goal of negotiations was the creation of a single North Atlantic Alliance based on security guarantees and mutual commitments between Europe and North America."
    },
    {
        "question": "Which countries were invited by the Brussels Treaty powers to participate in the negotiation process for the North Atlantic Alliance?",
        "answer": "Denmark, Iceland, Italy, Norway, and Portugal were invited to participate in the negotiation process."
    },
    {
        "question": "When was the Washington Treaty signed, and what did it introduce?",
        "answer": "The Washington Treaty was signed in April 1949, and it introduced a common security system based on a partnership among the 12 participating countries."
    },
    {
        "question": "When did Greece and Turkey accede to the Washington Treaty?",
        "answer": "Greece and Turkey acceded to the Washington Treaty in 1952."
    },
    {
        "question": "When did the Federal Republic of Germany join the Alliance?",
        "answer": "The Federal Republic of Germany joined the Alliance in 1955."
    },
    {
        "question": "Which countries joined NATO in 1999, according to the text?",
        "answer": "The Czech Republic, Hungary, and Poland joined NATO in 1999."
    },
    {
        "question": "Which seven countries were invited to begin accession talks and formally acceded to the treaty in March 2004?",
        "answer": "Bulgaria, Estonia, Latvia, Lithuania, Romania, Slovakia, and Slovenia were invited to begin accession talks and formally acceded to the treaty in March 2004."
    },  {
        "question": "What were the countries that initially participated in the negotiation process for the North Atlantic Alliance?",
        "answer": "Denmark, Iceland, Italy, Norway, and Portugal were initially invited to participate in the negotiation process."
    },
    {
        "question": "When did Spain become a member of NATO?",
        "answer": "Spain became a member of NATO in 1982."
    },
    {
        "question": "What was the status of the former German Democratic Republic (East Germany) after the unification of Germany?",
        "answer": "After the unification of Germany in 1990, the former German Democratic Republic came under the security protection of the Alliance as an integral part of the united country."
    },
    {
        "question": "When did the Czech Republic, Hungary, and Poland join NATO?",
        "answer": "The Czech Republic, Hungary, and Poland joined NATO in 1999."
    },
    {
        "question": "Which group of countries were invited to begin accession talks and formally acceded to the treaty in March 2004?",
        "answer": "Seven countries, including Bulgaria, Estonia, Latvia, Lithuania, Romania, Slovakia, and Slovenia, were invited to begin accession talks and formally acceded to the treaty in March 2004."
    },
    {
        "question": "What was the significance of the Washington Treaty in the context of the North Atlantic Alliance?",
        "answer": "The Washington Treaty introduced a common security system based on a partnership among the participating countries and marked a significant development in the establishment of the North Atlantic Alliance."
    }
           
           ], 
           
    'The North Atlantic Alliance was founded on the basis of a treaty between member states entered into freely by each of them after public debate and due parliamentary process. The Treaty upholds their individual rights as well as their international obligations in accordance with the Charter of the United Nations. Through the treaty, member countries commit themselves to sharing the risks and responsibilities of collective security and undertake not to enter into any other international commitments which might conflict with the treaty':
           [
    {
        "question": "What document upholds member states' international obligations?",
        "answer": "The Treaty upholds their international obligations in accordance with the Charter of the United Nations."
    },
    {
        "question": "What is the core commitment of member countries through the treaty?",
        "answer": "Member countries commit themselves to sharing the risks and responsibilities of collective security through the treaty."
    },
    {
        "question": "What restriction do member countries agree to in the treaty regarding international commitments?",
        "answer": "Member countries undertake not to enter into any other international commitments which might conflict with the treaty."
    },
    {
        "question": "What is the role of public debate and due parliamentary process in entering into the treaty?",
        "answer": "Member states entered into the treaty freely after public debate and due parliamentary process."
    },
    {
        "question": "What international obligations are upheld by the Treaty?",
        "answer": "The Treaty upholds member states' individual rights as well as their international obligations in accordance with the Charter of the United Nations."
    }, 
                {
        "question": "What is the basis of the founding of the North Atlantic Alliance?",
        "answer": "The North Atlantic Alliance was founded on the basis of a treaty between member states."
    },
    {
        "question": "How did member states enter into the treaty?",
        "answer": "Member states entered into the treaty freely after public debate and due parliamentary process."
    },
    {
        "question": "What does the Treaty uphold?",
        "answer": "The Treaty upholds their individual rights as well as their international obligations in accordance with the Charter of the United Nations."
    },
    {
        "question": "What do member countries commit to through the treaty?",
        "answer": "Member countries commit themselves to sharing the risks and responsibilities of collective security through the treaty."
    },
    {
        "question": "What do member countries undertake not to do regarding international commitments?",
        "answer": "Member countries undertake not to enter into any other international commitments which might conflict with the treaty."
    }
], 
           "Since NATO’s creation more than half a century ago, its central focus has been to provide for the immediate defence and security of its member countries. Today this remains its core task, but its main focus has undergone fundamental changes to enable the Alliance to confront new threats and meet new challenges.": [
    {
        "question": "What has been NATO's central focus since its creation?",
        "answer": "NATO's central focus since its creation has been to provide for the immediate defense and security of its member countries."
    },
    {
        "question": "Has NATO's core task changed over the years?",
        "answer": "No, NATO's core task remains to provide for the immediate defense and security of its member countries."
    },
    {
        "question": "What fundamental changes has NATO undergone in its main focus?",
        "answer": "NATO has undergone fundamental changes in its main focus to enable the Alliance to confront new threats and meet new challenges."
    },
    {
        "question": "Is the immediate defense and security of member countries still a primary concern for NATO?",
        "answer": "Yes, the immediate defense and security of member countries remains a primary concern for NATO."
    },
    {
        "question": "How has NATO adapted to changing circumstances?",
        "answer": "NATO has adapted by changing its main focus to confront new threats and challenges while maintaining its core task of providing defense and security for member countries."
    }, 
               {
        "question": "What is NATO's core task according to the text?",
        "answer": "NATO's core task is to provide for the immediate defense and security of its member countries."
    },
    {
        "question": "Has NATO's primary mission changed significantly over time?",
        "answer": "No, NATO's primary mission, which is to provide for the immediate defense and security of its member countries, remains consistent."
    },
    {
        "question": "What kinds of changes has NATO made to its main focus?",
        "answer": "NATO has made fundamental changes to its main focus in order to address new threats and challenges."
    },
    {
        "question": "Is the immediate defense and security of member countries still a central concern for NATO today?",
        "answer": "Yes, the immediate defense and security of member countries continues to be a central concern for NATO."
    },
    {
        "question": "How has NATO evolved to respond to changing circumstances?",
        "answer": "NATO has evolved by adapting its main focus to address new threats and challenges while upholding its core task of providing defense and security for member countries."
    }
], 
           "NATO’s fundamental security tasks NATO’s essential and enduring purpose, set out in the Washington Treaty, is to safeguard the freedom and security of all its members by political and military means. Based on common values of democracy, human rights and the rule of law, the Alliance has striven since its inception to secure a lasting peaceful order in Europe. However, the achievement of this aim can be jeopardised by crisis and conflict outside the Euro-Atlantic area. The Alliance therefore not only ensures the defence of its members but contributes to peace and stability beyond the geographical space defined as the North Atlantic Treaty area through partnerships and crisis management operations." : [
    {
        "question": "What is NATO's fundamental purpose as defined in the Washington Treaty?",
        "answer": "NATO's fundamental purpose, as set out in the Washington Treaty, is to safeguard the freedom and security of all its members by political and military means."
    },
    {
        "question": "What values form the basis of NATO's mission?",
        "answer": "NATO's mission is based on common values of democracy, human rights, and the rule of law."
    },
    {
        "question": "What has NATO striven to achieve since its inception?",
        "answer": "Since its inception, NATO has striven to secure a lasting peaceful order in Europe."
    },
    {
        "question": "What can jeopardize the achievement of NATO's aim for a lasting peaceful order in Europe?",
        "answer": "The achievement of NATO's aim for a lasting peaceful order in Europe can be jeopardized by crisis and conflict outside the Euro-Atlantic area."
    },
    {
        "question": "What does the Alliance do to contribute to peace and stability beyond the North Atlantic Treaty area?",
        "answer": "The Alliance contributes to peace and stability beyond the North Atlantic Treaty area through partnerships and crisis management operations."
    }, 
               {
        "question": "What are the common values on which NATO's mission is based?",
        "answer": "NATO's mission is based on common values of democracy, human rights, and the rule of law."
    },
    {
        "question": "What has NATO aimed to achieve in Europe since its inception?",
        "answer": "Since its inception, NATO has aimed to secure a lasting peaceful order in Europe."
    },
    {
        "question": "What can pose a threat to the achievement of NATO's aim for a peaceful order in Europe?",
        "answer": "Crisis and conflict outside the Euro-Atlantic area can pose a threat to the achievement of NATO's aim for a peaceful order in Europe."
    },
    {
        "question": "How does NATO contribute to peace and stability beyond its defined geographical area?",
        "answer": "NATO contributes to peace and stability beyond the North Atlantic Treaty area through partnerships and crisis management operations."
    },
    {
        "question": "What is the primary purpose of NATO, as stated in the Washington Treaty?",
        "answer": "The primary purpose of NATO, as stated in the Washington Treaty, is to safeguard the freedom and security of all its members through political and military means."
    }
],         
"The guiding principle by which the Alliance works is common commitment and mutual cooperation among sovereign states in support of the indivisibility of security for all its members. Solidarity and cohesion within the Alliance, through daily cooperation in both the political and military spheres, guarantee that no single member country is forced to rely upon its own national efforts alone in dealing with basic security challenges. Without depriving member countries of their right and duty to assume their sovereign responsibilities in the field of defence, the Alliance enables them through collective efforts to meet their essential national security objectives." : [
    {
        "question": "What is the guiding principle by which the Alliance works?",
        "answer": "The guiding principle by which the Alliance works is common commitment and mutual cooperation among sovereign states in support of the indivisibility of security for all its members."
    },
    {
        "question": "What does solidarity and cohesion within the Alliance guarantee?",
        "answer": "Solidarity and cohesion within the Alliance guarantee that no single member country is forced to rely upon its own national efforts alone in dealing with basic security challenges."
    },
    {
        "question": "How does the Alliance enable member countries to meet their essential national security objectives?",
        "answer": "The Alliance enables member countries to meet their essential national security objectives through collective efforts."
    },
    {
        "question": "Does the Alliance deprive member countries of their right and duty to assume sovereign responsibilities in defense?",
        "answer": "No, the Alliance does not deprive member countries of their right and duty to assume their sovereign responsibilities in the field of defense."
    },
    {
        "question": "What is the key goal of solidarity and cooperation within the Alliance?",
        "answer": "The key goal of solidarity and cooperation within the Alliance is to ensure that no member country has to face basic security challenges on its own."
    }, 
    {
        "question": "What is the goal of common commitment and mutual cooperation among sovereign states in the Alliance?",
        "answer": "The goal of common commitment and mutual cooperation is to support the indivisibility of security for all Alliance members."
    },
    {
        "question": "How does the Alliance ensure that member countries do not rely solely on their own national efforts for basic security challenges?",
        "answer": "Solidarity and cohesion within the Alliance, through daily cooperation in both the political and military spheres, ensure that no single member country is forced to rely upon its own national efforts alone in dealing with basic security challenges."
    },
    {
        "question": "What does the Alliance enable member countries to do in terms of their essential national security objectives?",
        "answer": "The Alliance enables member countries, through collective efforts, to meet their essential national security objectives."
    },
    {
        "question": "Is there a conflict between the Alliance's collective efforts and member countries' sovereign responsibilities in defense?",
        "answer": "No, the Alliance does not deprive member countries of their right and duty to assume their sovereign responsibilities in the field of defense."
    },
    {
        "question": "What is the primary aim of solidarity and cooperation within the Alliance?",
        "answer": "The primary aim of solidarity and cooperation within the Alliance is to ensure that no member country is left to face basic security challenges alone."
    }
], 
           "NATO’s fundamental security tasks are described in the Alliance’s Strategic Concept. It is the authoritative statement of the Alliance’s objectives and provides the highest level of guidance on the political and military means to be used in achieving them. It remains the basis for the implementation of Alliance policy as a whole. However, changing threats and threat perceptions have resulted in a continuous process of adaptation of this strategy to ensure that the political framework, military structures and military capabilities needed to deal with modern security challenges are all in place.":[
    {
        "question": "Where are NATO's fundamental security tasks described?",
        "answer": "NATO's fundamental security tasks are described in the Alliance's Strategic Concept."
    },
    {
        "question": "What is the Strategic Concept's role in the Alliance?",
        "answer": "The Strategic Concept is the authoritative statement of the Alliance's objectives and provides the highest level of guidance on the political and military means to be used in achieving them. It remains the basis for the implementation of Alliance policy as a whole."
    },
    {
        "question": "Why has the Alliance adapted its strategy over time?",
        "answer": "The Alliance has adapted its strategy to ensure that the political framework, military structures, and military capabilities needed to deal with modern security challenges are in place, given changing threats and threat perceptions."
    },
    {
        "question": "What does the Strategic Concept serve as for the Alliance?",
        "answer": "The Strategic Concept serves as the authoritative statement of the Alliance's objectives and provides guidance on how to achieve them."
    },
    {
        "question": "What drives the continuous process of adaptation of NATO's strategy?",
        "answer": "The continuous process of adaptation of NATO's strategy is driven by changing threats and threat perceptions, which necessitate the alignment of political frameworks, military structures, and capabilities with modern security challenges."
    }, 
               {
        "question": "What is the highest level of guidance provided by the Strategic Concept?",
        "answer": "The Strategic Concept provides the highest level of guidance on the political and military means to achieve the Alliance's objectives."
    },
    {
        "question": "What remains the basis for the implementation of Alliance policy as a whole?",
        "answer": "The Strategic Concept remains the basis for the implementation of Alliance policy as a whole."
    },
    {
        "question": "What has driven the need for the continuous adaptation of NATO's strategy?",
        "answer": "Changing threats and threat perceptions have driven the need for the continuous adaptation of NATO's strategy to align with modern security challenges."
    },
    {
        "question": "What is the role of the Strategic Concept in guiding the Alliance's actions?",
        "answer": "The Strategic Concept serves as the authoritative statement of the Alliance's objectives and provides guidance on the political and military means to achieve them."
    },
    {
        "question": "What does NATO focus on in its adaptation process?",
        "answer": "NATO focuses on ensuring that the political framework, military structures, and military capabilities needed to address modern security challenges are in place during the adaptation process."
    }
], 
     "The Strategic Concept, first published in 1991, differed dramatically from preceding documents both in content and form. It maintained the security of its members as NATO’s fundamental purpose but combined this with the specific obligation to work towards improved and expanded security for Europe as a whole through partnership and cooperation with former adversaries. In addition, it was issued as a public document, open for discussion and comment by parliaments, security specialists, journalists and the broader public. The Strategic Concept was revised in 1999, committing the Allies not only to common defence but to the peace and stability of the wider Euro-Atlantic area. It comprises the following political elements: a broad approach to security, encompassing political, economic, social and environmental factors, as well as the Alliance’s defence dimension.a strong commitment to transatlantic relations. maintenance of Alliance military capabilities to ensure the effectiveness of military operations. development of European capabilities within the Alliance. maintenance of adequate conflict prevention and crisis management structures and procedures.effective partnerships with non-NATO countries based on cooperation and dialogue. the enlargement of the Alliance and an open door policy towards potential new members.continuing efforts towards far-reaching arms control, disarmament and non-proliferation agreements." : [
    {
        "question": "When was the Strategic Concept first published?",
        "answer": "The Strategic Concept was first published in 1991."
    },
    {
        "question": "How did the 1991 Strategic Concept differ from preceding documents?",
        "answer": "The 1991 Strategic Concept differed from preceding documents both in content and form. It combined the security of its members with the obligation to work towards improved and expanded security for Europe as a whole through partnership and cooperation with former adversaries."
    },
    {
        "question": "What was significant about the 1991 Strategic Concept in terms of its accessibility?",
        "answer": "The 1991 Strategic Concept was issued as a public document and was open for discussion and comment by parliaments, security specialists, journalists, and the broader public."
    },
    {
        "question": "When was the Strategic Concept revised, and what did it commit the Allies to?",
        "answer": "The Strategic Concept was revised in 1999, committing the Allies not only to common defense but also to the peace and stability of the wider Euro-Atlantic area."
    },
    {
        "question": "What are some of the political elements included in the Strategic Concept?",
        "answer": "The Strategic Concept comprises various political elements, including a broad approach to security, a strong commitment to transatlantic relations, maintenance of Alliance military capabilities, development of European capabilities within the Alliance, maintenance of conflict prevention and crisis management structures, effective partnerships with non-NATO countries, the enlargement of the Alliance, and efforts towards arms control, disarmament, and non-proliferation agreements."
    }, 
         {
        "question": "What significant change did the 1991 Strategic Concept bring compared to preceding documents?",
        "answer": "The 1991 Strategic Concept combined the security of NATO members with the obligation to work towards improved and expanded security for Europe through partnership and cooperation with former adversaries."
    },
    {
        "question": "Who was the 1991 Strategic Concept open for discussion and comment by?",
        "answer": "The 1991 Strategic Concept was open for discussion and comment by parliaments, security specialists, journalists, and the broader public."
    },
    {
        "question": "What did the 1999 revision of the Strategic Concept commit the Allies to?",
        "answer": "The 1999 revision of the Strategic Concept committed the Allies not only to common defense but also to the peace and stability of the wider Euro-Atlantic area."
    },
    {
        "question": "What are some of the political elements included in the Strategic Concept?",
        "answer": "The Strategic Concept includes political elements such as a broad approach to security, a strong commitment to transatlantic relations, maintenance of Alliance military capabilities, development of European capabilities within the Alliance, maintenance of conflict prevention and crisis management structures, effective partnerships with non-NATO countries, and efforts towards arms control, disarmament, and non-proliferation agreements."
    },
    {
        "question": "What was the core purpose maintained in the Strategic Concept?",
        "answer": "The core purpose maintained in the Strategic Concept was the security of NATO members."
    }
], 
           "This broad definition of security recognises the importance of political, economic, social and environmental factors in addition to the defence dimension. Partnership and cooperation with other countries, cooperation with other regional and international organisations such as the United Nations, and the strategic partnership that is evolving between NATO and the European Union all contribute to the establishment of mutually reinforcing and complementary relations and to more effective conflict prevention and crisis management." :  [
    {
        "question": "What does the broad definition of security in NATO recognize as important factors?",
        "answer": "The broad definition of security in NATO recognizes the importance of political, economic, social, and environmental factors, in addition to the defense dimension."
    },
    {
        "question": "What contributes to more effective conflict prevention and crisis management according to the text?",
        "answer": "Partnership and cooperation with other countries, cooperation with other regional and international organizations such as the United Nations, and the strategic partnership evolving between NATO and the European Union all contribute to more effective conflict prevention and crisis management."
    },
    {
        "question": "What is the significance of partnership and cooperation in NATO's approach to security?",
        "answer": "Partnership and cooperation with other countries are significant elements in NATO's approach to security, as they contribute to mutually reinforcing and complementary relations and more effective conflict prevention and crisis management."
    },
    {
        "question": "Which international organization is mentioned in the text as part of NATO's cooperation efforts?",
        "answer": "The United Nations is mentioned in the text as an international organization with which NATO cooperates."
    },
    {
        "question": "What is the impact of NATO's strategic partnership with the European Union?",
        "answer": "NATO's strategic partnership with the European Union contributes to mutually reinforcing and complementary relations, as well as more effective conflict prevention and crisis management."
    }, 
               {
        "question": "What factors are recognized as important in the broad definition of security within NATO?",
        "answer": "The broad definition of security in NATO recognizes the importance of political, economic, social, and environmental factors, in addition to the defense dimension."
    },
    {
        "question": "How does partnership and cooperation with other countries contribute to NATO's approach to security?",
        "answer": "Partnership and cooperation with other countries are significant elements in NATO's approach to security, as they contribute to mutually reinforcing and complementary relations and more effective conflict prevention and crisis management."
    },
    {
        "question": "Which international organization does NATO cooperate with, as mentioned in the text?",
        "answer": "NATO cooperates with other regional and international organizations, including the United Nations."
    },
    {
        "question": "What does the evolving strategic partnership between NATO and the European Union contribute to?",
        "answer": "The evolving strategic partnership between NATO and the European Union contributes to mutually reinforcing and complementary relations, as well as more effective conflict prevention and crisis management."
    },
    {
        "question": "Why does NATO emphasize cooperation with other countries and organizations in the text?",
        "answer": "NATO emphasizes cooperation with other countries and organizations because it contributes to more effective conflict prevention and crisis management."
    }
], 
           
           
           
           

     
           
}

# %%
The Strategic Concept, first published in 1991, differed dramatically from preceding documents both in content and form. It maintained the security of its members as NATO’s fundamental purpose but combined this with the specific obligation to work towards improved and expanded security for Europe as a whole through partnership and cooperation with former adversaries. In addition, it was issued as a public document, open for discussion and comment by parliaments, security specialists, journalists and the broader public. The Strategic Concept was revised in 1999, committing the Allies not only to common defence but to the peace and stability of the wider Euro-Atlantic area. It comprises the following political elements: a broad approach to security, encompassing political, economic, social and environmental factors, as well as the Alliance’s defence dimension.a strong commitment to transatlantic relations. maintenance of Alliance military capabilities to ensure the effectiveness of military operations. development of European capabilities within the Alliance. maintenance of adequate conflict prevention and crisis management structures and procedures.effective partnerships with non-NATO countries based on cooperation and dialogue. the enlargement of the Alliance and an open door policy towards potential new members.continuing efforts towards far-reaching arms control, disarmament and non-proliferation agreements.
# Out:
# 11

# %%
from bardapi import Bard

from dotenv import load_dotenv
import os

load_dotenv()
token = os.getenv('API_KEY')

bard = Bard(token = "cghf-rnm82d_ZtxeSn0_yLl6Tg0zCUNkhZu7qOYJBtvhSodtiNha5mK9TeUyoeqpv36nMg.")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [115], in <cell line: 9>()
#       6 load_dotenv()
#       7 token = os.getenv('API_KEY')
# ----> 9 bard = Bard(token = "cghf-rnm82d_ZtxeSn0_yLl6Tg0zCUNkhZu7qOYJBtvhSodtiNha5mK9TeUyoeqpv36nMg.")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\bardapi\core.py:78, in Bard.__init__(self, token, timeout, proxies, session, conversation_id, google_translator_api_key, language, run_code, token_from_browser)
#      76 self.choice_id = ""
#      77 self.session = self._get_session(session)
# ---> 78 self.SNlM0e = self._get_snim0e()
#      79 self.language = language or os.getenv("_BARD_API_LANG")
#      80 self.run_code = run_code
#
# File ~\AppData\Roaming\Python\Python39\site-packages\bardapi\core.py:149, in Bard._get_snim0e(self)
#     145 resp = self.session.get(
# ...

# %%
index = 0
dict = {}
for i in arr1[:5]:
    result = bard.get_answer('Generate Question answer from the given corpus without images: """{}"""'.format(i))
    #print(result['content'])
    x = result['content']
    y = x.split('**Question:**')
    for j, i in enumerate(y):
        if j == 0:
            continue
        i = i.split('**Answer:**')
        dict[i[0].strip()] = i[1].strip()
    
    result = bard.get_answer('Generate few more from the corpus without images')
    #print(result['content'])
    x = result['content']
    y = x.split('**Question:**')
    for j, i in enumerate(y):
        if j == 0:
            continue
        i = i.split('**Answer:**')
        dict[i[0].strip()] = i[1].strip()
     
    print(index)
    index+= 1

    if index == 5:
        break
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
dict
# Out:
# {'What are the three core tasks of NATO?': 'The three core tasks of NATO are:\n1. Collective defense: NATO is committed to defending its member states against aggression or the threat of aggression.\n2. Crisis prevention and management: NATO works to prevent and manage crises through political and military means.\n3. Cooperative security: NATO promotes cooperation and security with non-member countries.',
# ...

# %%
# Out:
# 1633

# %%
dict
# Out:
# {'What is the North Atlantic Alliance?': 'The North Atlantic Alliance is a political and military alliance between 30 North American and European countries. It was founded in 1949 to provide collective security against the Soviet Union, and it has since evolved to address a wide range of security challenges, including terrorism, cyberwarfare, and regional conflicts.',
#  'What are the principles of the North Atlantic Alliance?': 'The North Atlantic Alliance is based on the principles of democracy, individual liberty, and the rule of law. Member countries commit themselves to upholding these principles both domestically and internationally.',
#  'What is the purpose of the North Atlantic Treaty?': 'The purpose of the North Atlantic Treaty is to safeguard the freedom and security of its members through political and military means. The treaty includes a collective defense clause, which means that an attack against one member country is considered an attack against all.',
# ...

# %%
x = d2['content']
x
# Out:
# "Here are some more question-and-answer pairs that can be generated from the given corpus:\n\n**Question:** What are the benefits of being a NATO member country?\n**Answer:** The benefits of being a NATO member country include:\n* Collective defense: NATO member countries are guaranteed the protection of all other members in the event of an attack.\n* Consultation and cooperation: NATO member countries can consult and cooperate on a wide range of security issues, including intelligence sharing, crisis management, and defense planning.\n* Deterrence: NATO's credible military capability deters aggression against its members.\n* Promotion of democracy and human rights: NATO promotes democracy and human rights throughout the Euro-Atlantic area.\n\n**Question:** How has NATO evolved since its founding in 1949?\n**Answer:** NATO has evolved significantly since its founding in 1949. The Alliance has expanded its membership from 12 to 30 countries, and its mission has grown to include a wide
# ...

# %%
dict = {}
y = x.split('**Question:**')
for j, i in enumerate(y):
    if j == 0:
        continue
    i = i.split('**Answer:**')
    dict[i[0].strip()] = i[1].strip()

# %%
dict
# Out:
# {'What are the benefits of being a NATO member country?': "The benefits of being a NATO member country include:\n* Collective defense: NATO member countries are guaranteed the protection of all other members in the event of an attack.\n* Consultation and cooperation: NATO member countries can consult and cooperate on a wide range of security issues, including intelligence sharing, crisis management, and defense planning.\n* Deterrence: NATO's credible military capability deters aggression against its members.\n* Promotion of democracy and human rights: NATO promotes democracy and human rights throughout the Euro-Atlantic area.",
# ...

# %%
import requests
from bardapi import Bard

# Set your Bard API key
API_KEY = "AIzaSyDwK4oXrU96nFNXrnT8wCPVBjTpUizBV4o"

# Define the input text and the desired task
input_text = "What is the capital of France?"
task = "retrieve"

# Create a POST request to the Bard API endpoint
url = "https://bard.googleapis.com/v1/tasks"
headers = {
    "Authorization": "Bearer " + API_KEY,
}
data = {
    "input_text": input_text,
    "task": task,
}

# Send the request and receive the response
response = requests.post(url, headers=headers, data=data)

# Parse the JSON response
output = response

# Print the output text
print(output)
# Out:
# <Response [404]>

# %%
import docx2txt
import re 
import numpy as np
import pandas as pd

mytext = docx2txt.process(r"C:\Users\HASHIM RAZI\Downloads\nato handbook (1).docx")

text = mytext.split(' ')
#print(my_text)
#print(mytext)
arr = ["Part I", "Part II",  "PART III", "PART IV", "PART V", "PART VI", "PART VII", "PART VIII", "PART IX", "PART X", "The Strategic Commanders have a staff representative on each board"]

# %%
pip install docx2txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\hashim razi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hashim razi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hashim razi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hashim razi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hashim razi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hashim razi\appdata\roaming\python\python39\site-packages)
# ...

# %%
arr = ['An introduction to the Alliance', 'Policy and decision-making', 'NATO’s civilian and military structures', "The Alliance's role in peacekeeping and peace-support operations", 'Combating new threats and developing new capabilities', 'The opening up of the Alliance to new member countries', 'Partnership and cooperation', "NATO-EU RELATIONS", "The wider institutional framework for security", "Programmes, Activities, Organisations and Agencies", "The Strategic Commanders have a staff representative on each board"]start = arr[0]
end = arr[1]

li = mytext.find(start)
mi = mytext.find(end)

# %%
li
# Out:
# 498

# %%
if li != -1 and mi != -1:
    txt = mytext[li :mi]
    #print(extracted_text)
else:
    print("Markers not found in the paragraph.")
    
x = []
for i in txt.split('\n'):
    x.append(i)

# %%
x
# Out:
# ['An introduction to the Alliance',
#  '',
#  '',
#  '',
#  '\xa0',
#  '',
#  '',
#  '',
#  '\xa0',
#  '',
#  '',
#  '',
#  'What is NATO?',
#  '',
#  'The North Atlantic Treaty Organisation is an alliance of 26 countries from North America and Europe committed to fulfilling the goals of the North Atlantic Treaty signed in Washington on 4 April 1949.',
#  '',
#  'In accordance with the Treaty, the fundamental role of NATO is to safe- guard the freedom and security of its member countries by political and military means. NATO safeguards the Allies’ common values of democracy, individual liberty, the rule of law and the peaceful resolution of disputes and promotes these values throughout the Euro-Atlantic area. It provides a forum in which countries from North America and Europe can consult together on security issues of common concern and take joint action in addressing them.',
#  '',
# ...

# %%
s = ' '
arr = []
for i in x:
    if len(i) >= 2:
        y = re.findall('\w.+', i)
        z = y[0]
        if ("CHAPTER" in z) or ("Chapter"  in z):
            continue
            
        if ':' in z[-1]:
            z.replace(':', '')
            s += z
            continue
        
        if ';' in z[-1]:
            z = z.replace(';',',')
            s += z
            continue
    
        if '.' not in z[-1]:
            s += z
            
        else:
            if len(s) > 1:
                arr.append(s)
            else:
                arr.append(z)
                
            s = ' '

# %%
arr = ["AN INTRODUCTION TO THE ALLIANCE", "POLICY AND DECISION-MAKING",  "NATO’S CIVILIAN AND MILITARY STRUCTURES", "THE ALLIANCE’S ROLE IN PEACEKEEPING AND PEACE-SUPPORT OPERATIONS", "COMBATING NEW THREATS AND DEVELOPING NEW CAPABILITIES", "THE OPENING UP OF THE ALLIANCE TO NEW MEMBER COUNTRIES", "PARTNERSHIP AND COOPERATION", "NATO-EU RELATIONS", "THE WIDER INSTITUTIONAL FRAMEWORK FOR SECURITY", "PROGRAMMES, ACTIVITIES, ORGANISATIONS AND AGENCIES", "The Strategic Commanders have a staff representative on each board"]

# %%
#arr = ["Part I", "Part II",  "PART III", "PART IV", "PART V", "PART VI", "PART VII", "PART VIII", "PART IX", "PART X", "The Strategic Commanders have a staff representative on each board"]
arr = ['An introduction to the Alliance', 'Policy and decision-making', 'NATO’s civilian and military structures', "The Alliance's role in peacekeeping and peace-support operations", 'Combating new threats and developing new capabilities', 'The opening up of the Alliance to new member countries', 'Partnership and cooperation', "NATO-EU RELATIONS", "The wider institutional framework for security", "Programmes, Activities, Organisations and Agencies", "The Strategic Commanders have a staff representative on each board"]
count = 0
arr1 = []

while count != 10:
    nextcount = count
    start = arr[count]
    end = arr[nextcount+1]

    li = mytext.find(start)
    mi = mytext.find(end)
    
    
    
    
    
    
    # extracting text
    
    if li != -1 and mi != -1:
        txt = mytext[li + len(start):mi]
    #print(extracted_text)
    else:
        print("Markers not found in the paragraph.")

    x = []
    for i in txt.split('\n\n'):
        x.append(i)
        
        
    # appending text
    
    
    s = ' '
    for i in x:
        if len(i) >= 3:
            y = re.findall('\w.+', i)
            z = y[0]
            if ("CHAPTER" in z) or ("Chapter"  in z):
                continue

            if ':' in z[-1]:
                z.replace(':', '')
                s += z
                continue

            if ';' in z[-1]:
                z = z.replace(';',',')
                s += z
                continue

            if '.' not in z[-1]:
                s += z

            else:
                if len(s) > 1:
                    s+=z
                    arr1.append(s)
                else:
                    arr1.append(z)

                s = ' '
                
        
        
        
    
    
    
    #print(arr1)
    count+=1

# %%
arr1
# Out:
# [' What is NATO?The North Atlantic Treaty Organisation is an alliance of 26 countries from North America and Europe committed to fulfilling the goals of the North Atlantic Treaty signed in Washington on 4 April 1949.',
#  'In accordance with the Treaty, the fundamental role of NATO is to safe- guard the freedom and security of its member countries by political and military means. NATO safeguards the Allies’ common values of democracy, individual liberty, the rule of law and the peaceful resolution of disputes and promotes these values throughout the Euro-Atlantic area. It provides a forum in which countries from North America and Europe can consult together on security issues of common concern and take joint action in addressing them.',
# ...

# %%
from bardapi import Bard

from dotenv import load_dotenv
import os

# load_dotenv()
# token = os.getenv('API_KEY')   

bard = Bard(token = "cghf-rwk6-52-MlT4q0_OraiAiLZ1vhETSHMsb9Oudm7qOiXP8VoPXQ-H-Xa5CkMcJFosg.")
# Out:
# {'content': "**Questions:**\n\n* What is NATO?\n* What is the purpose of NATO?\n* What are NATO's core values?\n* How many member countries does NATO have?\n* When was NATO founded?\n* Where is the North Atlantic Treaty signed?\n\n**Answers:**\n\n* NATO is an alliance of 26 countries from North America and Europe committed to fulfilling the goals of the North Atlantic Treaty.\n* The purpose of NATO is to safeguard the freedom and security of its member countries by political and military means.\n* NATO's core values are democracy, individual liberty, the rule of law and the peaceful resolution of disputes.\n* NATO has 26 member countries.\n* NATO was founded on April 4, 1949.\n* The North Atlantic Treaty was signed in Washington, D.C.\n\nI hope this is helpful!",
#  'conversation_id': 'c_e06040e30321828d',
#  'response_id': 'r_e06040e3032182f0',
#  'factuality_queries': None,
#  'text_query': ['what is the role of NATO', 1],
#  'choices': [{'id': 'rc_e06040e3032184df',
# ...

# %%
result = bard.get_answer('Generate Question answer from the given corpus in dictionary format with question as key and answer as value without images: """The guiding principle by which the Alliance works is common commitment and mutual cooperation among sovereign states in support of the indivisibility of security for all its members. Solidarity and cohesion within the Alliance, through daily cooperation in both the political and military spheres, guarantee that no single member country is forced to rely upon its own national efforts alone in dealing with basic security challenges. Without depriving member countries of their right and duty to assume their sovereign responsibilities in the field of defence, the Alliance enables them through collective efforts to meet their essential national security objectives. """')
result['content']
# Out:
# 'Response Error: b\')]}\\\'\\n\\n38\\n[["wrb.fr",null,null,null,null,[7]]]\\n54\\n[["di",57],["af.httprm",57,"6516768015723120728",3]]\\n25\\n[["e",4,null,null,129]]\\n\'. \nUnable to get response.\nPlease double-check the cookie values and verify your network environment or google account.'

# %%
x = result['content']

# %%
y = x.split('\n\n')[1]
y.split('questions')
st = re.search('{', y)
en = re.search('}', y)
start = st.start()
end = en.start()
d = y[start+1:end]
d = d.strip()[:-1]
d = "{" + d + '}'
dict = json.loads(d)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [297], in <cell line: 1>()
# ----> 1 y = x.split('\n\n')[1]
#       2 y.split('questions')
#       3 st = re.search('{', y)
#
# IndexError: list index out of range

# %%
dict
# Out:
# {'What is NATO?': 'The North Atlantic Treaty Organisation (NATO)',
#  'What is the purpose of NATO?': 'To safeguard the freedom and security of its member countries by political and military means.',
#  "What are NATO's core values?": 'Democracy, individual liberty, the rule of law, and the peaceful resolution of disputes.',
#  'How many member countries does NATO have?': '26',
#  'When was NATO founded?': 'April 4, 1949',
#  'Where was the North Atlantic Treaty signed?': 'Washington, D.C.'}
