# %%
import requests
latitude="28.697522"
longitude="77.140681"
user_key='3754f0440b3026cde542ed69af9f499a'
basic_api='https://developers.zomato.com/api/v2.1'
header={"User-agent": "curl/7.43.0",'Accept': 'application/json','user-key':user_key}
params={'lat':latitude,'lon':longitude,'cuisines':193,'sort':'real_distance','count':10}
response=requests.get(basic_api+'/search',headers=header,params=params)
for i in response.json().get('restaurants'):
    print(i.get('restaurant').get('name'),i.get('restaurant').get('user_rating').get('aggregate_rating'),i.get('restaurant').get('R').get('res_id'),i.get('restaurant').get('location').get('locality'))
# Out:
# Themis Barbecue House 4.2 18204820 Netaji Subhash Place
# Tandoori Nights 0 19661940 Pitampura
# UBQ by Barbeque Nation 3.6 18889769 Netaji Subhash Place
# Barbeque Nation 4.2 9561 Netaji Subhash Place
# Amazings Kitchen 0 19370424 Prashant Vihar
# Anytime Chicken 0 19520153 Shalimar Bagh
# UBQ by Barbeque Nation 4.0 19082741 Lawrence Road
# Moet's Barbeque 0 19238917 Alipur
# BBQ Express By The Barbeque Company 4.0 19494102 Punjabi Bagh
# UBQ by Barbeque Nation 3.7 18889760 Rohini

# %%
import requests
latitude="28.697522"
longitude="77.140681"
user_key='3754f0440b3026cde542ed69af9f499a'
basic_api='https://developers.zomato.com/api/v2.1'
header={"User-agent": "curl/7.43.0",'Accept': 'application/json','user-key':user_key}
params={'lat':latitude,'lon':longitude,'cuisines':193,'sort':'real_distance','count':10}
response=requests.get(basic_api+'/search',headers=header,params=params)
for i in response.json().get('restaurants'):
    print(i.get('restaurant').get('name'),i.get('restaurant').get('user_rating').get('aggregate_rating'),i.get('restaurant').get('R').get('res_id'),i.get('restaurant').get('location').get('locality'))
response.json()
# Out:
# Themis Barbecue House 4.2 18204820 Netaji Subhash Place
# Tandoori Nights 0 19661940 Pitampura
# UBQ by Barbeque Nation 3.6 18889769 Netaji Subhash Place
# Barbeque Nation 4.2 9561 Netaji Subhash Place
# Amazings Kitchen 0 19370424 Prashant Vihar
# Anytime Chicken 0 19520153 Shalimar Bagh
# UBQ by Barbeque Nation 4.0 19082741 Lawrence Road
# Moet's Barbeque 0 19238917 Alipur
# BBQ Express By The Barbeque Company 4.0 19494102 Punjabi Bagh
# UBQ by Barbeque Nation 3.7 18889760 Rohini
# {'results_found': 222,
#  'results_start': 0,
#  'results_shown': 10,
#  'restaurants': [{'restaurant': {'R': {'res_id': 18204820,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': '3754f0440b3026cde542ed69af9f499a',
#     'id': '18204820',
#     'name': 'Themis Barbecue House',
#     'url': 'https://www.zomato.com/ncr/themis-barbecue-house-netaji-subhash-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Shop 251, 2nd Floor, Near Stanmax Aggarwal Millennium Tower 1, Netaji Subhash Place, New Delhi',
#      'locality': 'Netaji Subhash Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6939101917',
#      'longitude': '77.1492858231',
#      'zipcode': '110035',
#      'country_id': 1,
#      'locality_verbose': 'Netaji Subhash Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, BBQ, Mughlai, Desserts, Beverages',
#     'timings': '11:30am – 5pm, 6:30pm – 12midnight (Mon-Sun)',
#     'average_cost_for_two': 1400,
#     'price_range': 3,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Debit Card',
#      'Cash',
#      'Credit Card',
#      'Takeaway Available',
#      'Lunch',
#      'Delivery',
#      'Live Music',
#      'Air Conditioned',
#      'Fullbar',
#      'Table booking recommended',
#      'Family Friendly',
#      'Live Sports Screening',
#      'Rooftop',
#      'Smoking Area',
#      'Indoor Seating',
#      'Buffet'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/18204820/494ae2f3eb8614a2389b3dda0afc7ed9.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.2',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.2'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 3238},
#     'all_reviews_count': 2164,
#     'photos_url': 'https://www.zomato.com/ncr/themis-barbecue-house-netaji-subhash-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 4598,
#     'menu_url': 'https://www.zomato.com/ncr/themis-barbecue-house-netaji-subhash-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/18204820/494ae2f3eb8614a2389b3dda0afc7ed9.jpg',
#     'medio_provider': True,
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18204820',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/themis-barbecue-house-netaji-subhash-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9821656569, +91 9821657571, +91 9821656562',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Lounge'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 19661940,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': '3754f0440b3026cde542ed69af9f499a',
#     'id': '19661940',
#     'name': 'Tandoori Nights',
#     'url': 'https://www.zomato.com/ncr/tandoori-nights-pitampura-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Main Circle, Near TV Tower, Pitampura, New Delhi',
#      'locality': 'Pitampura',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6994200717',
#      'longitude': '77.1521866322',
#      'zipcode': '110034',
#      'country_id': 1,
#      'locality_verbose': 'Pitampura, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'BBQ',
#     'timings': '7 PM to 11 PM (Mon, Wed-Sun), Tue Closed',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['No Seating Available',
#      'Cash',
#      'Takeaway Available',
#      'Dinner',
#      'Delivery'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': 0,
#      'rating_text': 'Not rated',
#      'rating_color': 'CBCBCB',
#      'rating_obj': {'title': {'text': 'NEW'},
#       'bg_color': {'type': 'grey', 'tint': '400'}},
#      'votes': 3,
#      'custom_rating_text': 'NEW',
#      'custom_rating_text_background': '#89959B',
#      'rating_tool_tip': 'This restaurant is newly opened. The rating will appear once the restaurant completes 60 days in operation.'},
#     'all_reviews_count': 3,
#     'photos_url': 'https://www.zomato.com/ncr/tandoori-nights-pitampura-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 3,
#     'menu_url': 'https://www.zomato.com/ncr/tandoori-nights-pitampura-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19661940',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/tandoori-nights-pitampura-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9711551800',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Kiosk'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 18889769,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': '3754f0440b3026cde542ed69af9f499a',
#     'id': '18889769',
#     'name': 'UBQ by Barbeque Nation',
#     'url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-netaji-subhash-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '101 & 102, A-7, Agarwal Corporate Heights, Pitampura Road, Netaji Subhash Place, New Delhi',
#      'locality': 'Netaji Subhash Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6925958359',
#      'longitude': '77.1512823924',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Netaji Subhash Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, BBQ, Biryani, Beverages',
#     'timings': '11:30 AM to 11 PM',
#     'average_cost_for_two': 450,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['No Seating Available',
#      'Cash',
#      'Delivery',
#      'Dinner',
#      'Lunch'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.6',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.6'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 1039},
#     'all_reviews_count': 165,
#     'photos_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-netaji-subhash-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 43,
#     'menu_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-netaji-subhash-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18889769',
#     'order_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-netaji-subhash-place-new-delhi/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-netaji-subhash-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '011 64806060',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': [],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 9561,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': '3754f0440b3026cde542ed69af9f499a',
#     'id': '9561',
#     'name': 'Barbeque Nation',
#     'url': 'https://www.zomato.com/ncr/barbeque-nation-netaji-subhash-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '101 - 102, 1st Floor, Agarwal Corporate Heights, Netaji Subhash Place, New Delhi',
#      'locality': 'Netaji Subhash Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6924099601',
#      'longitude': '77.1515180916',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Netaji Subhash Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, BBQ, Beverages, Desserts',
#     'timings': '11:30am – 3:30pm, 6pm – 9pm (Mon-Sun)',
#     'average_cost_for_two': 1500,
#     'price_range': 3,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Seating Available',
#      'Cash',
#      'Takeaway Available',
#      'Dinner',
#      'Delivery',
#      'Credit Card',
#      'Debit Card',
#      'Fullbar',
#      'Buffet',
#      'Desserts and Bakes',
#      'Indoor Seating',
#      'Air Conditioned'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/2/1212/ba0ace0f3ce2794fbd54cc762ea3de8f.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.2',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.2'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 2091},
#     'all_reviews_count': 964,
#     'photos_url': 'https://www.zomato.com/ncr/barbeque-nation-netaji-subhash-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 1612,
#     'menu_url': 'https://www.zomato.com/ncr/barbeque-nation-netaji-subhash-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/2/1212/ba0ace0f3ce2794fbd54cc762ea3de8f.jpg?output-format=webp',
#     'medio_provider': True,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/9561',
#     'order_url': 'https://www.zomato.com/ncr/barbeque-nation-netaji-subhash-place-new-delhi/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/ncr/barbeque-nation-netaji-subhash-place-new-delhi/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/ncr/barbeque-nation-netaji-subhash-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '080 35095800',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 19370424,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': '3754f0440b3026cde542ed69af9f499a',
#     'id': '19370424',
#     'name': 'Amazings Kitchen',
#     'url': 'https://www.zomato.com/ncr/amazings-kitchen-prashant-vihar-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'G-5, RG Complex 1 Sector 14, Prashant Vihar, New Delhi',
#      'locality': 'Prashant Vihar',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.7154000000',
#      'longitude': '77.1360460000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Prashant Vihar, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, Chinese, Fast Food, BBQ',
#     'timings': '12 Noon to 12 Midnight',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Standing Tables',
#      'Takeaway Available',
#      'Lunch',
#      'Cash',
#      'Free Parking',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': 0,
#      'rating_text': 'Not rated',
#      'rating_color': 'CBCBCB',
#      'rating_obj': {'title': {'text': '-'},
#       'bg_color': {'type': 'grey', 'tint': '400'}},
#      'votes': 0},
#     'all_reviews_count': 0,
#     'photos_url': 'https://www.zomato.com/ncr/amazings-kitchen-prashant-vihar-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 1,
#     'menu_url': 'https://www.zomato.com/ncr/amazings-kitchen-prashant-vihar-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'medio_provider': False,
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19370424',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/amazings-kitchen-prashant-vihar-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8383990221',
#     'all_reviews': {'reviews': []},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 19520153,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': '3754f0440b3026cde542ed69af9f499a',
#     'id': '19520153',
#     'name': 'Anytime Chicken',
#     'url': 'https://www.zomato.com/ncr/anytime-chicken-shalimar-bagh-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Al -113/114, 3rd Floor, Shalimar Bagh, New Delhi',
#      'locality': 'Shalimar Bagh',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.7039903645',
#      'longitude': '77.1618353052',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Shalimar Bagh, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'BBQ, Charcoal Chicken, Fast Food, Kebab, Mughlai, North Indian, Roast Chicken',
#     'timings': '11 AM to 10:30 PM',
#     'average_cost_for_two': 300,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Dinner',
#      'Takeaway Available',
#      'Delivery',
#      'Cash',
#      'Standing Tables',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': 0,
#      'rating_text': 'Not rated',
#      'rating_color': 'CBCBCB',
#      'rating_obj': {'title': {'text': '-'},
#       'bg_color': {'type': 'grey', 'tint': '400'}},
#      'votes': 0},
#     'all_reviews_count': 0,
#     'photos_url': 'https://www.zomato.com/ncr/anytime-chicken-shalimar-bagh-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 1,
#     'menu_url': 'https://www.zomato.com/ncr/anytime-chicken-shalimar-bagh-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19520153',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/anytime-chicken-shalimar-bagh-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 7982904724',
#     'all_reviews': {'reviews': []},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 19082741,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': '3754f0440b3026cde542ed69af9f499a',
#     'id': '19082741',
#     'name': 'UBQ by Barbeque Nation',
#     'url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-lawrence-road-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'C-35/17, Industrial Area, Lawrence Road, New Delhi',
#      'locality': 'Lawrence Road',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6799125869',
#      'longitude': '77.1508445218',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Lawrence Road, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, BBQ, Biryani, Beverages',
#     'timings': '10 AM to 10 PM',
#     'average_cost_for_two': 450,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['No Seating Available',
#      'Cash',
#      'Lunch',
#      'Dinner',
#      'Breakfast',
#      'Delivery'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 1176},
#     'all_reviews_count': 258,
#     'photos_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-lawrence-road-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 44,
#     'menu_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-lawrence-road-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19082741',
#     'order_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-lawrence-road-new-delhi/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-lawrence-road-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8130974029',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': [],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 19238917,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': '3754f0440b3026cde542ed69af9f499a',
#     'id': '19238917',
#     'name': "Moet's Barbeque",
#     'url': 'https://www.zomato.com/ncr/moets-barbeque-alipur-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '1, DDA Market, Alipur, New Delhi',
#      'locality': 'Alipur',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6919060000',
#      'longitude': '77.1642980000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Alipur, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, BBQ',
#     'timings': '11 AM to 12 Noon',
#     'average_cost_for_two': 550,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Takeaway Available',
#      'Debit Card',
#      'Lunch',
#      'Cash',
#      'Credit Card',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': 0,
#      'rating_text': 'Not rated',
#      'rating_color': 'CBCBCB',
#      'rating_obj': {'title': {'text': '-'},
#       'bg_color': {'type': 'grey', 'tint': '400'}},
#      'votes': 1},
#     'all_reviews_count': 1,
#     'photos_url': 'https://www.zomato.com/ncr/moets-barbeque-alipur-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 1,
#     'menu_url': 'https://www.zomato.com/ncr/moets-barbeque-alipur-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'medio_provider': False,
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19238917',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/moets-barbeque-alipur-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9920960870',
#     'all_reviews': {'reviews': [{'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 19494102,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': '3754f0440b3026cde542ed69af9f499a',
#     'id': '19494102',
#     'name': 'BBQ Express By The Barbeque Company',
#     'url': 'https://www.zomato.com/ncr/bbq-express-by-the-barbeque-company-punjabi-bagh-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Ground Floor, Building 28, Central Market, Punjabi Bagh, New Delhi',
#      'locality': 'Punjabi Bagh',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6712426551',
#      'longitude': '77.1337805626',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Punjabi Bagh, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'BBQ, North Indian, Mughlai, Chinese, Momos',
#     'timings': '1pm – 12midnight (Mon-Sun)',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['No Seating Available',
#      'Dinner',
#      'Delivery',
#      'Lunch',
#      'Cash'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/19494098/289b5a8d1d76221178f931704e378a60.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 56},
#     'all_reviews_count': 36,
#     'photos_url': 'https://www.zomato.com/ncr/bbq-express-by-the-barbeque-company-punjabi-bagh-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 10,
#     'menu_url': 'https://www.zomato.com/ncr/bbq-express-by-the-barbeque-company-punjabi-bagh-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/19494098/289b5a8d1d76221178f931704e378a60.jpg?output-format=webp',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19494102',
#     'order_url': 'https://www.zomato.com/ncr/bbq-express-by-the-barbeque-company-punjabi-bagh-new-delhi/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/bbq-express-by-the-barbeque-company-punjabi-bagh-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9311244775, +91 9311241002, +91 9711884358',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': [],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 18889760,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': '3754f0440b3026cde542ed69af9f499a',
#     'id': '18889760',
#     'name': 'UBQ by Barbeque Nation',
#     'url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-rohini-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '601, 6th Floor, Unity One, MLCP Plot, Rohini West Metro Station Complex, Rohini, New Delhi',
#      'locality': 'Rohini',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.7151087735',
#      'longitude': '77.1163898706',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Rohini, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, BBQ, Biryani, Beverages',
#     'timings': '11 AM to 12 Midnight',
#     'average_cost_for_two': 450,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['No Seating Available',
#      'Dinner',
#      'Delivery',
#      'Lunch',
#      'Cash',
#      'Takeaway Available'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.7',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.7'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 1814},
#     'all_reviews_count': 223,
#     'photos_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-rohini-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 47,
#     'menu_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-rohini-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18889760',
#     'order_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-rohini-new-delhi/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/ubq-by-barbeque-nation-rohini-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 7026456060',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': [],
#     'establishment_types': []}}]}
