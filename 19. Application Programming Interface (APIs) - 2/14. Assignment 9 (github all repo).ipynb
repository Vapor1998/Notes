# %%
## client id = 038ebcd6d0527312ef3d
## client secret = b79e3c40f0ae43f5ee724c32e48ba8065ff955f8

# %%
import requests
import json

r = requests.get("https://github.com/login/oauth/authorize", params = {'client_id':'038ebcd6d0527312ef3d', 'redirect_uri':'https://www.google.com/', 'state':'random_123'})
print(r.url)
# Out:
# https://github.com/login?client_id=038ebcd6d0527312ef3d&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3D038ebcd6d0527312ef3d%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%252F%26state%3Drandom_123

# %%
## code is = f5b2e6ca5698c6dc6590


r = requests.post('https://github.com/login/oauth/access_token', auth = ('038ebcd6d0527312ef3d', 'b79e3c40f0ae43f5ee724c32e48ba8065ff955f8'),
                  data = {'code':'5094e8a42dc7fd518adf', 'redirect_uri':'https://www.google.com/'}, headers = {'User-Agent': 'hashimrazi'})
print(r.text)
# Out:
# access_token=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&scope=&token_type=bearer

# %%
j =1
h = {'Authorization': 'token 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', 'Accept':'application/vnd.github.baptiste-preview+json'}
for i in range(8):
    r = requests.get('https://api.github.com/orgs/fossasia/repos', headers = h, params={'type':'all', 'page':j} )
    data =  r.json()
    for i in data:
        print(i['name'])

    j +=1
# Out:
# x-mario
# phimpme-android
# phimpme-drupal
# xmario_buildscript
# pslab-case
# meilix-systemlock
# fossasia10-drupal
# fossasia11-drupal
# blog.fossasia.org
# 2010.fossasia.org
# 2014.fossasia.org
# meilix
# phimpme-wordpress
# 2015.fossasia.org
# badge-magic-android
# api.fossasia.net
# directory.api.fossasia.net
# common.api.fossasia.net
# cmap.api.fossasia.net
# feed.api.freifunk.net
# feed.api.fossasia.net
# fossasia-communities
# sg18.sciencehack.asia
# gci14.fossasia.org
# fossasia-nodemailer
# 2011.fossasia.org
# 2012.fossasia.org
# labs.fossasia.org
# fossasia.net
# foss.vn
# libregraphics.asia
# perspektive89.com
# susi_smart_box
# hotelxoai.com
# yaydoc-artwork
# fossasia-companion-android
# loklak_webclient
# circle-knitting
# open-event-attendee-android
# 2018.fossasia.org
# open-event
# open-event-droidgen
# open-event-wsgen
# open-event-server
# knitweb
# knitpat
# knitlib
# pslab-expeyes
# timeline.api.fossasia.net
# 2016.fossasia.org
# fossasia.org
# pslab-sister
# ...
