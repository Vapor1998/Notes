# %%
## client id = 038ebcd6d0527312ef3d
## client secret = b79e3c40f0ae43f5ee724c32e48ba8065ff955f8

# %%
import requests
import json

r = requests.get("https://github.com/login/oauth/authorize", params = {'client_id':'038ebcd6d0527312ef3d', 'redirect_uri':'https://www.google.com/', 'state':'random_123'})
print(r.url)
# Out:
# https://github.com/login?client_id=038ebcd6d0527312ef3d&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3D038ebcd6d0527312ef3d%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%252F%26state%3Drandom_123

# %%
## code is = f5b2e6ca5698c6dc6590


r = requests.post('https://github.com/login/oauth/access_token', auth = ('038ebcd6d0527312ef3d', 'b79e3c40f0ae43f5ee724c32e48ba8065ff955f8'),
                  data = {'code':'053edecc82016a496a9c', 'redirect_uri':'https://www.google.com/'}, headers = {'User-Agent': 'hashimrazi'})
print(r.text)
# Out:
# access_token=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&scope=&token_type=bearer

# %%
h = {'Authorization': 'token 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'}
r = requests.get('  https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors', headers = h)
data =  r.json()
for i in data:
    print( i['author']['login'], i['total'])
# Out:
# Sherawat42 15
# tushartuteja 5
# Rawal27 13

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import json
import requests

data={"client_id":"171b2fccb73d64507b96", "redirect_uri":"https://www.google.com", "state":"Welcome", "scope":"repo"}
response=requests.get("https://github.com/login/oauth/authorize", params=data)
print(response.url)

# # response


data={"client_id":"171b2fccb73d64507b96", "client_secret":"58e5b908893c969d63e9d87ecb8d72011032a611",
     "code":"a374a499cc81d1f5199d", "redirect_uri":"https://www.google.com", "state":"Welcome"}
r=requests.post("https://github.com/login/oauth/access_token", data=data, headers={"accept":"application/json"})
print(r.text)


# r=requests.get('    https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors',
#                headers={"Authorization":"token 8b73e47fd2e638b283bec11f94b16d76004b84fa"})
# r
# # data=r.json()
# # print(data)
# # #for i in data:
# #  #   print(i['author']['login'],['total'])
# Out:
# https://github.com/login?client_id=171b2fccb73d64507b96&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3D171b2fccb73d64507b96%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%26scope%3Drepo%26state%3DWelcome

# %%
data={"client_id":"171b2fccb73d64507b96", "client_secret":"58e5b908893c969d63e9d87ecb8d72011032a611",
     "code":"a374a499cc81d1f5199d", "redirect_uri":"https://www.google.com", "state":"Welcome"}
r=requests.post("https://github.com/login/oauth/access_token", data=data)
print(r.text)
# Out:
# error=bad_verification_code&error_description=The+code+passed+is+incorrect+or+expired.&error_uri=https%3A%2F%2Fdocs.github.com%2Fapps%2Fmanaging-oauth-apps%2Ftroubleshooting-oauth-app-access-token-request-errors%2F%23bad-verification-code

# %%
import json
import requests

data={"client_id":"7196f29726add4d9a4b3", "redirect_uri":"https://www.google.com", "state":"Welcome", "scope":"repo"}
response=requests.get("https://github.com/login/oauth/authorize", params=data)

# %%
print(response.url)
# Out:
# https://github.com/login?client_id=7196f29726add4d9a4b3&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3D7196f29726add4d9a4b3%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%26scope%3Drepo%26state%3DWelcome

# %%
data={"client_id":"7196f29726add4d9a4b3", "client_secret":"1fb1af3d6c41958553a99df5cede3e15fca831c3",
     "code":"d7ad4d6b5b6fa955d085", "redirect_uri":"https://www.google.com", "state":"Welcome"}
r=requests.post("https://github.com/login/oauth/access_token", data=data, headers={"accept":"application/json"})
print(r.text)
# Out:
# {"access_token":"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","token_type":"bearer","scope":"repo"}

# %%
h = {'Authorization': 'token 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'}

r=requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors',
               headers=h)
data=r.json()

for i in data:
    print( i['author']['login'], i['total'])
# Out:
# Sherawat42 15
# tushartuteja 5
# Rawal27 13

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import requests
from requests.auth import HTTPBasicAuth
ans = requests.get("https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors", auth = HTTPBasicAuth('aditya-ml', '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'))
ans=ans.json()
print(ans)
# Out:
# [{'total': 15, 'weeks': [{'w': 1483228800, 'a': 0, 'd': 0, 'c': 0}, {'w': 1483833600, 'a': 0, 'd': 0, 'c': 0}, {'w': 1484438400, 'a': 313, 'd': 419, 'c': 4}, {'w': 1485043200, 'a': 64, 'd': 24, 'c': 5}, {'w': 1485648000, 'a': 195, 'd': 19, 'c': 6}, {'w': 1486252800, 'a': 0, 'd': 0, 'c': 0}, {'w': 1486857600, 'a': 0, 'd': 0, 'c': 0}, {'w': 1487462400, 'a': 0, 'd': 0, 'c': 0}, {'w': 1488067200, 'a': 0, 'd': 0, 'c': 0}, {'w': 1488672000, 'a': 0, 'd': 0, 'c': 0}, {'w': 1489276800, 'a': 0, 'd': 0, 'c': 0}, {'w': 1489881600, 'a': 0, 'd': 0, 'c': 0}, {'w': 1490486400, 'a': 0, 'd': 0, 'c': 0}, {'w': 1491091200, 'a': 0, 'd': 0, 'c': 0}, {'w': 1491696000, 'a': 0, 'd': 0, 'c': 0}, {'w': 1492300800, 'a': 0, 'd': 0, 'c': 0}, {'w': 1492905600, 'a': 0, 'd': 0, 'c': 0}, {'w': 1493510400, 'a': 0, 'd': 0, 'c': 0}, {'w': 1494115200, 'a': 0, 'd': 0, 'c': 0}, {'w': 1494720000, 'a': 0, 'd': 0, 'c': 0}, {'w': 1495324800, 'a': 0, 'd': 0, 'c': 0}, {'w': 1495929600, 'a': 0, 'd': 0, 'c': 0}, {'w': 1496534400, 
# ...

# %%
import requests as req
header = {"Authorization":"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"}
response = req.get("https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors",headers = header)
python = response.json()
#print(response.url)
python
# Out:
# [{'total': 15,
#   'weeks': [{'w': 1483228800, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1483833600, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1484438400, 'a': 313, 'd': 419, 'c': 4},
#    {'w': 1485043200, 'a': 64, 'd': 24, 'c': 5},
#    {'w': 1485648000, 'a': 195, 'd': 19, 'c': 6},
#    {'w': 1486252800, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1486857600, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1487462400, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1488067200, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1488672000, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1489276800, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1489881600, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1490486400, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1491091200, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1491696000, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1492300800, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1492905600, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1493510400, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1494115200, 'a': 0, 'd': 0, 'c': 0},
#    {'w': 1494720000, 'a': 0, 'd': 0, 'c': 0},
# ...
