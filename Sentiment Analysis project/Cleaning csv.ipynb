# %%
import re
import numpy as np
import pandas as pd
import re
import numpy as np
import re
import pandas as pd
from textblob import TextBlob
import nltk
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

df = pd.read_csv('Iphone14Reviews.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Product', 'Review', '5 Stars', '4 Stars', '3 Stars',
#        '2 Stars', '1 Stars', 'Avg Rating', 'Price', 'Link'],
#       dtype='object')

# %%
# df.drop('Unnamed: 0.2', axis = 1, inplace = True)
# df.drop('Unnamed: 0.1', axis = 1, inplace = True)
df.drop('Unnamed: 0', axis = 1, inplace = True)
# df.drop('Unnamed: 0.4', axis = 1, inplace = True)
# df.drop('Unnamed: 0.4', axis = 1, inplace = True)
#df.drop('Unnamed: 0.3', axis = 1, inplace = True)
#df.drop('Cleaned', axis = 1, inplace = True)

# %%
df
# Out:
#                                            Product  \
# 0                    Apple iPhone 14 (128GB, Blue)
# 1                    Apple iPhone 14 (128GB, Blue)
# 2                    Apple iPhone 14 (128GB, Blue)
# 3                    Apple iPhone 14 (128GB, Blue)
# 4                    Apple iPhone 14 (128GB, Blue)
# ...                                            ...
# 2992  Apple iPhone 14 Pro Max (1 TB) - Space Black
# 2993  Apple iPhone 14 Pro Max (1 TB) - Space Black
# 2994  Apple iPhone 14 Pro Max (1 TB) - Space Black
# 2995  Apple iPhone 14 Pro Max (1 TB) - Space Black
# 2996  Apple iPhone 14 Pro Max (1 TB) - Space Black
#
#                                                  Review 5 Stars 4 Stars  \
# 0                              Its a very good product.     172      20
# 1                                           So far good     172      20
# 2                                             Wonderful     172      20
# 3                                                  Good     172      20
# 4                                 Very good performance     172      20
# ...                                                 ...     ...     ...
# 2992                                                NaN     49%      8%
# 2993  This is my Personal & primary (main) MobileNew...     49%      8%
# 2994  Insane battery life . I'm happy with purchase....     49%      8%
# 2995  Specifications good,but seems repeated you may...     49%      8%
# 2996  genuine product can’t buy anything better than...     49%      8%
#
#      3 Stars 2 Stars 1 Stars    Avg Rating             Price  \
# 0          2       4       6      ['4.7 ']  [' ₹70,990.00 ']
# 1          2       4       6      ['4.7 ']  [' ₹70,990.00 ']
# 2          2       4       6      ['4.7 ']  [' ₹70,990.00 ']
# 3          2       4       6      ['4.7 ']  [' ₹70,990.00 ']
# 4          2       4       6      ['4.7 ']  [' ₹70,990.00 ']
# ...      ...     ...     ...           ...               ...
# 2992     21%      0%     22%  3.6 out of 5         ₹1,89,900
# 2993     21%      0%     22%  3.6 out of 5         ₹1,89,900
# 2994     21%      0%     22%  3.6 out of 5         ₹1,89,900
# 2995     21%      0%     22%  3.6 out of 5         ₹1,89,900
# 2996     21%      0%     22%  3.6 out of 5         ₹1,89,900
#
#                                                    Link
# 0     https://www.croma.com/apple-iphone-14-128gb-bl...
# 1     https://www.croma.com/apple-iphone-14-128gb-bl...
# 2     https://www.croma.com/apple-iphone-14-128gb-bl...
# 3     https://www.croma.com/apple-iphone-14-128gb-bl...
# 4     https://www.croma.com/apple-iphone-14-128gb-bl...
# ...                                                 ...
# 2992  https://www.amazon.in/Apple-iPhone-Pro-Space-B...
# 2993  https://www.amazon.in/Apple-iPhone-Pro-Space-B...
# 2994  https://www.amazon.in/Apple-iPhone-Pro-Space-B...
# 2995  https://www.amazon.in/Apple-iPhone-Pro-Space-B...
# 2996  https://www.amazon.in/Apple-iPhone-Pro-Space-B...
#
# [2997 rows x 10 columns]

# %%
df.to_csv('Iphone14Reviews.csv', encoding ='utf-8')

# %%
import re
import numpy as np
import re
import pandas as pd
from textblob import TextBlob
import nltk
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
class Cleancsv:
    def __init__(self, df):
        self.df = df
    
    def clean(self, df):
        x = self.df['Avg Rating']
        for i, j in enumerate(x):
            if type(j) == list():
                j = j[0]
                y = re.sub(r'[^0-9.]+','', j)
                y = y+ '   '
                y = y[:3].strip()
                self.df.loc[i, 'Avg Rating'] = y
            else:
                if type(j) == str:
                    y = re.sub(r'[^0-9.]+','', j)
                    y = y+ '   '
                    y = y[:3].strip()
                    self.df.loc[i, 'Avg Rating'] = y


        # cleeaning price
        x = self.df['Price']
        index = 0
        for i in x:
            if type(i) == list:
                y = i[0]
                y = y.split('.')
                y = y[0]
                y = re.findall(r'\d', y)
                string = ' '
                for j in y:
                    string += j
                y = float(string)
                # print(y)
                self.df.loc[index, 'Price'] = y
            else:
                y = i
                if '\n' in y:
                    y = y.split('\n')
                    y = y[0]
                y = y.split('.')
                y = y[0]
                y = re.sub(r'[\n₹,]', '', y)
                y = re.findall(r'\d', y)
                string = ' '
                for j in y:
                    string += j
                if len(string) == 0 or len(string) == 1:
                    string = 0
                else:
                    y = float(string)
                # print(y)
                self.df.loc[index, 'Price'] = y

            index += 1
            
        # cleaning review
        cleaned = []
        for i in self.df['Review']:
            i = str(i)
            x = re.sub(r"[^a-zA-Z\s.,!?']", "", i)
            y = re.sub(r'READ MORE', '', x)
            # y = re.sub(r'[^\x00-\x7F]+', '', x)
            cleaned.append(y)

        # tokenizing
        token = []
        stop_words = set(stopwords.words('english'))
        for i in cleaned:
            word_tokens = word_tokenize(i)
            # print(word_tokens)
            filtered_words = [word for word in word_tokens if not word.lower() in stop_words]
            word = ' '.join(filtered_words)
            words = re.sub('[^a-zA-Z0-9 \n]', '', word)
            print(words)
            token.append(words)
        self.df['Cleaned1'] = token
        return self.df

    # print('-------------')
    def predict(self, data):
        def get_sentiment(text):
            return TextBlob(text).sentiment.polarity
        self.df['sentiment'] = self.df['Cleaned1'].apply(get_sentiment)
        sentiment = self.df['sentiment']
        avg = self.df.groupby('Product')['sentiment'].mean().sort_values(ascending=False)[:1]
        best_product = avg.index
        polarity = avg.values
        price = self.df.loc[self.df['Product'] == best_product[0], 'Price'].values[0]
        link = self.df.loc[self.df['Product'] == best_product[0], 'Link'].values[0]
        rate = self.df.loc[self.df['Product'] == best_product[0], 'Avg Rating'].values[0]

        return best_product, polarity, link, price, rate

# %%
x = Cleancsv(df)
df = x.clean(df)
# Out:
# good product
# far good
# Wonderful
# Good
# good performance
# Great Product
# Phone heats charging
# Great product
# nice
# Nice experience
# great
# Ok good
# Great
# Got best deal
# Could better
# Nice price good service
# Good experience
# good product
# Great product service
# Nice shopping experience  Got best price
# Battery life good thought would  Transferring android phone forgot use move iphone application  nt make mistake  Otherwise overall good phone  photos pretty good actually main reason spend much money behind lol   s apple yeah theres
# two ways  s great product  nt used iPhone  feels real good phone  great battery life  iOS really better stability speed
# Review week Overall powerful package photo  video gaming  thing could better battery  though works whole day low usage  extensive use would go beyond half dayCamera Pictures full zoom Sound quality Display Performance
# Nice camera battery drain fast specially video recording
# iPhone standout device Apple s latest lineup  sleek design  powerful hardware improved cameras  s musthave tech enthusiastPros Powerful hardware chip  Improved camera quality  Long battery life  Sleek design premium build quality  Improved display technology immersive experience  Great operating system large app storeCons Expensive compared smartphones  headphone jack
# mine rd IPhone Model iPhone Best one started android appleiPhone Best Camera Poor Battery Finally iPhone One best iPhone used fantastic camera Good battery life  Super fast face lock system  Good charger comparing old iPhones  Happy powerful iPhone
# Thanks Flipkart service fine nd comes daysproduct genuine nd love
# Best smartphone price range overall great performance  great camera great battery
# one problem facing keep phone charge heat phone Rest great
# Nice UI Fast
# Reasons get regular percent extra ram Better camera sensors Cinematic mode k fps could p fps Action mode super stabilised videos Better low light photos thanks photonic engine Better battery life Extra gpu core high graphics performance New improved modem fast efficient mobile connectivity Dual ambient light sensors Better camera flash Crash detection Satellite connectivity though currently
# Totally love new iphone  Battery backup amazing never expected Apple honestBuilt quality excellent looks premium  Camera quality excellent well  True life color reproduction  Indoor conditions amazing  night photos good  facial tones good  day clicks amazing  short s amazing exp  Selfie cam also produces good quality images
# nice photo bettery good show ok ok better one plus r etc anytime photo real u effect filtered
# love phone st time performance awesome wow camera quality battery everything awesome  prefer anyone use phone  Iphone using st time never getting problem  thank Flipkart providing low cost compared retail shops  Thank Flipkart Apple  love
# iPhone starlight beautiful design excellent camera great battery  think better previous year iPhone  Go
# Good
# Good product  battery drain issue G  Even dual sim  Also support dual G Sim switching Fast Satellite system also integrated phone easily track phone without internet connection  Awesome speed processor   mm jack  Wifi also thisDirect video call possible Phone Wireless charging heating issue detected Except heating regular full peak brightness use hr min  muc
# iPhone solid choice looking highquality smartphone experience  camera topnotch  performance smooth  design sleek modern  However  drawbacks consider comparing Android phonesOne biggest cons iPhone lack customization options  Apple strict policy apps features used devices  frustrating users want control pho
# Switched Xiaomi Pro heater means heats lot much cool device also used iPhone little bit better iPhone best device
# s perfect mobile  Comfortable hands  Size good  Looks classy  s best
# Apple iPhone great choice anyone looking reliable  fast stylish smartphone  inch OLED display delivers vibrant colors sharp details  powerful Bionic chip handles everything gaming multitasking ease  iPhone also improved camera system captures stunning photos videos lighting condition  thanks MP wideangle lens optical image stabilization  Smart HDR Action mode  iPh
# upgraded iPhone Plus  experienced huge improvement several areas daily usageI recommend buy iphone instead iphone various reasonsAdditional GB RAMLarger G antenna helps faster G speedImproved camerasCrash detectionSatellite connectivity send emergency messages
# wow first time shifting android iosn sooo amazing  phone excels everything camera haptics software experience  glad ordered iphone instead noticable camera improvement low light  ram makes future proof
# product genuinely awesome  ca nt stop etes looking product  Awesome work APPLE good customer support seller Flipkart  THANKS PRODUCT  GO
# Best smartphone price range overall great performance  great camera great battery
# one problem facing keep phone charge heat phone Rest great
# Nice UI Fast
# Reasons get regular percent extra ram Better camera sensors Cinematic mode k fps could p fps Action mode super stabilised videos Better low light photos thanks photonic engine Better battery life Extra gpu core high graphics performance New improved modem fast efficient mobile connectivity Dual ambient light sensors Better camera flash Crash detection Satellite connectivity though currently
# Totally love new iphone  Battery backup amazing never expected Apple honestBuilt quality excellent looks premium  Camera quality excellent well  True life color reproduction  Indoor conditions amazing  night photos good  facial tones good  day clicks amazing  short s amazing exp  Selfie cam also produces good quality images
# nice photo bettery good show ok ok better one plus r etc anytime photo real u effect filtered
# ...
# Nice
# like iphone sound quality camera ok ok zoom level low battery life also superb one time charge continue days fast chargingworth buy
# Value money  easy use  good craftsmanship  nice shade colour wow amazing product range
# Aaj h ata h android user phone user takes times adjust luving phn specially colour great software
# Loved  new colour really special
# nan
# New phone new feels  love apple make phone look like new model  new blue color mindblowing
# iPhone already broken got  also product genuine  paid  got first copy product
# ok camera poor quality batter us buy samsung glaxi ultra x zoom
# Upgraded years XS huge improvement battery  Improvement camera performance well  suggest go instead much difference
# mobile awesome made fewer upgradations previous segment
# Best phone yet apple masterpiece surelyCamera mp truly great upgrade
# New phone charging ke time bahut heat hota hai  Network connectivity bahut hi kharab hai mere dusre Android phone jaha full network rehta hai isme point network rehta hai Wifi connectivity range also poor
# product happy acquire
# already iOS user go  buy iphone
# lots interruptions bought st iPhone  Good looking performance impressive  Im also trust secure mobile  times Im getting irritated word AppStore applications Pay proceed
# Im getting G support phone  purchased month December in mobile settings showing g Im using Airtel network
# nt even see dynamic island pictures  fraud  Refrain buying iPhone online
# People saying Iphone would better choice think iphone better aspects  including camera battery  Great
# ProsImproved cameraLatest iOS resolved bugsCompact less weightPotrait shots gives better result ConsOld gen bionic chip
# Rate cheaper Flipkart
# phone absolutely fine Apple product giving previous version chip appreciableThe new action mode marvelousThe battery far better
# Good
# Planned Amazon exchange thought try iPhone iPhone disasterAmazon exchange turned faux  delivery guy seemed pre determined accepting old Samsung phone  wanted remove almost perfect tempered glass check screen  entered incorrect IMEI number phone mobile said system shows wrong IMEI exchange  wanted pay difference return delivery  Ended paying extra amount replace tempered glassI phone looks great outside UI flawlessProsSuper smooth touchGreat looks outsideNo junk apps preinstalledGood anti tracking Safari browserSafe message appWindows corporate apps work betterConsAverage photosPoor selfiesGo back function top screen painPoor file managementNo option add memory card iCloud upgrade comes priceFile transfer Bluetooth never worksOverall average experience
# Didnt receive ear buds lightning charger recieved phone nothing
# Camera Good Rather buying series go pro series Great Indian Sale much worthful price beast camera performance
# android user always blamed Apple weak battery performance flagship level phone  one blew away mind  Beautiful battery backup android phone give  Night photos superb sharp  still wish apple fingerprint sensor face id even though us superfast always display yr old samsung phone still phone nt  still happy especially get like  day battery backup heavy user  Cinematic mode literally amazing makes difference iphone  shoot k fps super clear quality  Overall love
# wan na buy  go pro pro max  use buying latest version nothing new except camera
# Looking buying another  awesome product perfecto gaming  Sound quality perfect  Waiting discount  Peace
# Nice almost Purchased Yet Buying time Feeling Good Apple Product
# apple products  phone much increased battery life  camera take low light photos  impressive ultra bionic processor makes gaming experience super smooth A worth buy
# Awesome  Loving
# advanced camera systems built quality phone  Display amazing video recording cinematic mode outstanding
# Iphone Bro  else say  Budget Big  Go Without Worries
# phoneApple phone without second delay  would say better android phones used  phone like water  flows way want shaping way  best way possible  phone designed show user wants eliminating unnecessary ads  features seen androidWhy better Android  pay much money Apple products  obviously experience features  physical components  camera lens etc  Apart basic things  also enjoy best applications available app store  developer might know app store policy application publish security posture towards handling payment apps etc  publish best application way apps  modules switches flawless  Due called strict policy privacy program Apple products  iPhone pop box screen apps wants track activity applications  respect apple show concern userApple phones  like vs reason may business practice followed th edition  please note iPhone making changes internally like physical components small change battery performance  lens edition  additional features may satisfy buy edition  find changes interesting  go  physical even cameras visually much different vs comparison  Also get cheap added features daily use  features real time use rare case  best part extra cost vs prices except extra k slashConcern must haveApple giving chargers silicon cases expensive good touch scratch friendly back due silk layer  issue sure  buy charger coming USB C claiming help carbon footprint  understandable customer friendly business model  Even purchase spend least k charger caseApple careI buying  pay phone already expensive premium apple care strict policy understand waste  Instead find private insurance make things better
# use wired Headphone adapter Bluetooth must kept exchange offer purchase amazon sends pre exchange instructions registered email  instruction clear neither easy follow unless one computer savvy  Old phone made prior ready else exchange bound refused  Pickup person utmost tries refuse exchange slightest pretext  Better expect help pickup  Need change settings workable battery backup  phones looks super classic far fully satisfied
# IPhone  else say  thing worried Hz refresh rate switching Hz Android phone  trust  difference big  think iOS optimised non issue
# Apple best phone  Red colour beautiful
# transition Android iOS little bumpy  well  Physically device joy  Battery life normal usage day half  great  features Android miss  hopefully ll get soonThis phone promises last long  needs tested
# Using st timephone awesomebattery back goodvery handy  doesnt hang uptrying understand features since new like way
# Product awesome classy absolutely beautiful  one thing note got heated sun extensive use
# Motion camera good rest features
# Battery life isnt great android phone  heavy user  Camera video quality beautiful  Processing anything phone fast  Good
# Awesome phonegreat camera  loved
# switched android iphone found iphone pretty fast camera quality good  branded product never fails
# phones kind robustness  look n feel  battery large screen experience  Real surround sounds unexpectedly little base unlike mobilesI using Iphone first time  first timers  device nirvanaBattery life amazingly longer anyone expectremember Nokia case  People make fun Iphones high price trust get paid forIphone Plus best deal want everything mobile dont want spend beyond lac
# Love phone  bigger display really adds value  happy purchase
# would recommend iphone feel VFM plus needs bigger screen better battery life  Android still lot catch especially battery management
# Extraordinary iphone
# good buy think money phone plus totaly waste
# Awesome phone
# worth money kind features offers yes plus looks better hand loves bigger size  Fits budget one doesnt want strech budget get pro max
# Loved
# Bids comparability advantage
# Good  Big hold single hand
# Video Player loadingPlay VideoPlayMuteCurrent Time Duration Loaded Stream Type LIVESeek live  currently behind liveLIVERemaining Time xPlayback RateChaptersChaptersDescriptionsdescriptions  selectedCaptionsCaptions  selectedEnglish AutomatedAudio Trackdefault  selectedFullscreenThis modal window  Upgraded XR plus  wanted go pro max didnt wanted spend lakh rupees opted go must say  good buy  camera  display battery  everything top notch
# always dont need see anything iphone even write reviews  Best phone thing wait offerPlus makes easier read books articles
# Dont dare compare mobiles iPhone bcoz best
# battery compare iphone basic bit better extra ordinary charging twice everydaydisplay brightness better sunlight otherwise usual iPhones market
# dream come true get iPhonefinally true
# Good
# Authorised dealer product Brand New  Packed sealed
#
# IP hold good battery backup hrs compared siblings  Abionic chip makes smoother  Since screen size large difficult hold use first fan big screens works like charm Camera improvements compared series unless need bigger screen  better battery backup advisable continue series  Pricing high Apple nothing
# Looks great blue
# Nice product
# Value money
# satisfied product
# Battery life ultimate
# Received defective product wouldnt charge  asked replacement Amazon  asked service denied report  Authorised Apple Care wont provide generally  basically stuck defective device  device sent apple care got part replaced expected Apple well  usually replace defective device
# Awesome
# Hey  big fan apple productsAt last buy new brand new iPhone plus  used month overall performance excellent compared iPhone iPhone iPhone plus screen size big battery capacity big so buy mobile  cost high cron  opinions overall performance excellent ProsDisplay Camera excellentBattery goodPerformance CrosCost Charger
# First time experience IOS  really different android
# nan
# Missing part
# Phone small thinerthan samsun otherwise con find itwow super display audio leg apps think never go android agintata android
# product perfection go also good battery life
# Good camera  battery backup upto days  sound output amazing  phone best consuming media best battery big screen  Go want balanced premium phone large display battery
# Phone good problem battery performance  ever forget unplug charger charge  instantly battery performance reduce Just one time forgot  charge daily  drawback found
# first Apple product  android user life  apple experience different  Camera battery performance awesome
# Although every thing good s heating lot browsing using camera application  anyone suggest whT
# Using iphone plus  Little bit improvement camera  much difference  big screen battery  Better buy pro
# Booked th October received product th October  Super fast delviery Amazon  Product genuineI Andriod user past years  apple products Macbook  Ipod Ipad  first time buying iphoneAfter using days give feedback belowPros Superb display Camera really good  think nobody beat Iphone camera pictures quality  Battery heavy usage got hours phone banking money transaction  apple highest security  Speed goodCons Apple incorporated Hz flash rate instead kept Hz model  call recording option  used Andriod  take time adjust IOS OS
# Genuine product
#
# Heating issues thought ok day two still persists
# Likes  mobile simply superb years using android device switched IPHONE precise performance butter smooth  cinematic camera awesome  look simple cool  Face unlock best among mobiles  Multitasking superbDislike  first day phone got hanged home screen alert hard reboot fortunately solution overcome  little bit worried saw  Front camera great per Iphone brand standard  Control center customizable s limited apps  Clear feature opened features androidOverall s good phone  got good deal along exchange offer
# Using last weekWorking smoothly cam quality also superb
# Nice
# Connect G jio mobile setting
# Awesome
# Awesome product
# Better Expectations
# thought deep purple case black thatd cool first got  indeed beautiful deep purple  fits perfectly  s grippy want  especially phone big slippy like matte cases  camera cover amazing  slides easily locks closed securely push open itll stay open photograph  easy clean protective long youre screenbreaker even rim raised enough typical drop onto flat surface would likely OK button holes port holes align perfectly  could better designed made thing Id like would blingy option
# purchasing iPhone Pro Max purple color concern protecting lenses looking durable elegant iPhone cases able find one purple  use one months recommend one  Good durability excellent value money
# Good
# got case hopes protecting camera lenses  beginning received  nice little tough slide camera cover open ve month  sliding cover became loose nt close properly
# Coming iPhone XR used happily complaints years  iPhone plus made huge upgrade  terms display  battery  camera etc   already iPhone  nt make sense go given upgrade negligible  older iPhone XXSXR  new iPhonePlus visual treatI wanted larger display without splurging Pro variant  love Apple introduced Plus variant something last iPhone  folks like meI ve plus gb variant day  initial thoughts  Battery absolute beast  box charge  hours later s touching mark fairly extensive usage browsing  gaming  streaming music  Make sure buy W charger reap fast charging benefits  Setup Butterysmooth onboarding  took mins transfer data old phone new one  bit trouble pairing Apple Watch plus though  nt best experiences  Display treat eyes  supersized  inch screen makes beautiful experience stream OTT content  play games  use camera photographyfilming  However  since display large  lot content tends look blurredout focus  Camera Gorgeous  gorgeous picture quality even low light   upgrade  people like  camera absolute delight  Build supersized  inch screen feels large hands  heavier iPhone XR  feels comfortable enough hold hours watch  browse game  words  despite mammoth size  feels light smaller iPhone counterparts  Colour Ordered lavender shade  s pronounced colour  daylight looks almost white  Delivery Preordered rd September  received th October days released  Kudos Amazon super prompt delivery  Verdict worthwhile option funds coming much older variant iPhone switching Android  pro  one feel like disappointmentWill update review continue using  far extremely impressed
# mainly starting looking phone best battery life  Im getting  daysyes DAYS  usage  Dang  Thats best battery life Ive seen phone Ive used farThe hz display doesnt matter  ultra smooth anyway  iPhones areThe screen great  Big  punchy  software stable  Face ID super helpful type passwords systemwideI get used added heft though  come Pixel  petite incher plastic shellThe one downside buying phone lockin magsafe  specifically purchase cases  car mounts  chargers etc cater  None existing modes compatible  including cable  Lightning  Damn  Apple  extras easily going pinch pocket  deeply  top premium paid purchasing iPhone India first place
# switched iPhone recently  dont words explain  awesome
# Bought Gb version thought pinnacle  However  realised called gold standard phone hardly provide comparable signal strength normal web surfing locations cell service great  almost k phone even compete Oneplus exchanged  Oneplus broken Oneplus  even talked apple services Singapore thinking received defective set got OS flashed completely  however  Qualcom Modem remained poorly active ever  Compared colleagues iphones upto Pro phones strugling signalSo  much Apple  Ha
# shift please dont extra features except action mode camera crash detection  buy new iPhone purchase save money
# used android user always wanted iPhone kept delaying  time thought going  got delivered one day  amazing  Everything perfect  People migrating android may find OS little difficult beginning time get used  One thing dont like use one whats app unlike android
# Switched iPhone android first time  Phone super smooth  excellent battery  super camera  best multimedia  Lightening port
# nan
# Personal primary main MobileNew Update Pro Max Dynamic Island replaces notchIf Currently using Pro Pro Max need change mobile  look wise difference
# Insane battery life  m happy purchase  Volume fantastic  Great photographs
# Specifications good  seems repeated may go wait new  Well seems like othersbest buy
# genuine product cant buy anything better  Worth price excellent camera must try love dynamic IslandYours faithfully

# %%
p, pol, l, pr, ra = x.predict(df)

# %%
p[0]

# %%
df

# %%
df.Review.fillna("No Review Available", inplace = True)
cleaned = []
for i in df['Review']:
    i = str(i)
    x = re.sub(r"[^a-zA-Z\s.,!?']", "", i)
    y = re.sub(r'READ MORE', '', x)
    # y = re.sub(r'[^\x00-\x7F]+', '', x)
    cleaned.append(y)

# %%
df.Review.isna().sum()
# Out:
# 0

# %%
df['Cleaned'] = cleaned

# %%
df
# Out:
#                                            Product  \
# 0                    Apple iPhone 14 (128GB, Blue)
# 1                    Apple iPhone 14 (128GB, Blue)
# 2                    Apple iPhone 14 (128GB, Blue)
# 3                    Apple iPhone 14 (128GB, Blue)
# 4                    Apple iPhone 14 (128GB, Blue)
# ...                                            ...
# 2992  Apple iPhone 14 Pro Max (1 TB) - Space Black
# 2993  Apple iPhone 14 Pro Max (1 TB) - Space Black
# 2994  Apple iPhone 14 Pro Max (1 TB) - Space Black
# 2995  Apple iPhone 14 Pro Max (1 TB) - Space Black
# 2996  Apple iPhone 14 Pro Max (1 TB) - Space Black
#
#                                                  Review 5 Stars 4 Stars  \
# 0                              Its a very good product.     172      20
# 1                                           So far good     172      20
# 2                                             Wonderful     172      20
# 3                                                  Good     172      20
# 4                                 Very good performance     172      20
# ...                                                 ...     ...     ...
# 2992                                No Review Available     49%      8%
# 2993  This is my Personal & primary (main) MobileNew...     49%      8%
# 2994  Insane battery life . I'm happy with purchase....     49%      8%
# 2995  Specifications good,but seems repeated you may...     49%      8%
# 2996  genuine product can’t buy anything better than...     49%      8%
#
#      3 Stars 2 Stars 1 Stars Avg Rating     Price  \
# 0          2       4       6        4.7   70990.0
# 1          2       4       6        4.7   70990.0
# 2          2       4       6        4.7   70990.0
# 3          2       4       6        4.7   70990.0
# 4          2       4       6        4.7   70990.0
# ...      ...     ...     ...        ...       ...
# 2992     21%      0%     22%        3.6  189900.0
# 2993     21%      0%     22%        3.6  189900.0
# 2994     21%      0%     22%        3.6  189900.0
# 2995     21%      0%     22%        3.6  189900.0
# 2996     21%      0%     22%        3.6  189900.0
#
#                                                    Link  \
# 0     https://www.croma.com/apple-iphone-14-128gb-bl...
# 1     https://www.croma.com/apple-iphone-14-128gb-bl...
# 2     https://www.croma.com/apple-iphone-14-128gb-bl...
# 3     https://www.croma.com/apple-iphone-14-128gb-bl...
# 4     https://www.croma.com/apple-iphone-14-128gb-bl...
# ...                                                 ...
# 2992  https://www.amazon.in/Apple-iPhone-Pro-Space-B...
# 2993  https://www.amazon.in/Apple-iPhone-Pro-Space-B...
# 2994  https://www.amazon.in/Apple-iPhone-Pro-Space-B...
# 2995  https://www.amazon.in/Apple-iPhone-Pro-Space-B...
# 2996  https://www.amazon.in/Apple-iPhone-Pro-Space-B...
#
#                                                Cleaned1  sentiment  \
# 0                                         good product    0.700000
# 1                                              far good   0.400000
# 2                                             Wonderful   1.000000
# 3                                                  Good   0.700000
# 4                                      good performance   0.700000
# ...                                                 ...        ...
# 2992                                                nan   0.000000
# 2993  Personal primary main MobileNew Update Pro Max...   0.211111
# 2994  Insane battery life  m happy purchase  Volume ...   0.250000
# 2995  Specifications good  seems repeated may go wai...   0.418182
# 2996  genuine product cant buy anything better  Wort...   0.450000
#
#                                                 Cleaned
# 0                              Its a very good product.
# 1                                           So far good
# 2                                             Wonderful
# 3                                                  Good
# 4                                 Very good performance
# ...                                                 ...
# 2992                                No Review Available
# 2993  This is my Personal  primary main MobileNew Up...
# 2994  Insane battery life . I'm happy with purchase....
# 2995  Specifications good,but seems repeated you may...
# 2996  genuine product cant buy anything better than ...
#
# [2997 rows x 13 columns]

# %%
# from here



min_price = df.loc[df.Price == df.Price.min()].index
max_price = df.loc[df.Price == df.Price.max()].index
mean_price = df.loc[df.Price == df.Price.mean()].index

mean = df.Price.mean()
std = df['Price'].std()

max_rating = df.loc[df["Avg Rating"] == df['Avg Rating'].max()].index


num_std = 0.09

ctm = df[(df['Price'] >= (mean - (num_std * std))) & (df['Price'] <= (mean + (num_std * std)))]

x = ctm.groupby('Product')['Review'].apply(list)

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Preprocessing and aspect extraction
def extract_aspects(text):
    
    se = []
    for i in text:
        x = nltk.word_tokenize(i)
        y = nltk.pos_tag(x)
        se.append(y)

    ar = {}
    aspect = []
    sent = []


    for i, j in enumerate(se):
        for k, l in enumerate(j):
            if l[1] == 'NN':
                aspect.append(l[0])
                sentences = ''
                for m in j[k:]:
                    sentences += ' ' + m[0]
                    if m[1] == 'JJ':
                        break
                sent.append(sentences.strip())
                ar[l[0]] = sentences
    return ar

sentence = x.values

#sent = extract_aspects(sentence)
def analyze_sentiment(text):
    # Initialize sentiment analyzer
    sid = SentimentIntensityAnalyzer()

    # Extract aspects from the text
    ar = extract_aspects(text)

    # Analyze sentiment for each aspect
    sentiment_scores = {}
    sentiment = {}
    
    for aspect, texts in ar.items():
        sentiment_scores[aspect] = sid.polarity_scores(texts)
        #sentiment[aspect] = sid.sentiment_valence(texts)
        

    return sentiment_scores, ar

# %%
senti = []
product_sentiment = {}
prod = x.index

k = 0
for i in x.values:
    sentiment, ar = analyze_sentiment(i)
    senti.append(sentiment)
    product_sentiment[prod[k]] = sentiment
    k+=1
    
t = list(product_sentiment.keys())[0]

product_sentiment[t]

# %%
def aspect_analysis(df):
    
    groupby_of_all = df.groupby('Product')['Cleaned'].apply(list)
    def extract_aspects(text):
    
        se = []
        for i in text:
            try:
                x = nltk.word_tokenize(i)
                y = nltk.pos_tag(x)
                se.append(y)
            except TypeError:
                print(type(i))
                pass

        ar = {}
        aspect = []
        sent = []


        for i, j in enumerate(se):
            for k, l in enumerate(j):
                if l[1] == 'NN':
                    aspect.append(l[0])
                    sentences = ''
                    for m in j[k:]:
                        sentences += ' ' + m[0]
                        if m[1] == 'JJ':
                            break
                    sent.append(sentences.strip())
                    ar[l[0]] = sentences
        return ar

    def analyze_sentiment(text):
        # Initialize sentiment analyzer
        sid = SentimentIntensityAnalyzer()

        # Extract aspects from the text
        ar = extract_aspects(groupby_of_all.values)

        # Analyze sentiment for each aspect
        sentiment_scores = {}
        sentiment = {}

        for aspect, texts in ar.items():
            sentiment_scores[aspect] = sid.polarity_scores(texts)
            #sentiment[aspect] = sid.sentiment_valence(texts)


        return sentiment_scores, ar
    
    senti = []
    product_sentiment = {}
    prod = groupby_of_all.index

    k = 0
    for i in groupby_of_all.values:
        sentiment, ar = analyze_sentiment(i)
        senti.append(sentiment)
        product_sentiment[prod[k]] = sentiment
        k+=1
        
    return product_sentiment

x = aspect_analysis(df)

# %%
groupby_of_all = df.groupby('Product')['Cleaned'].apply(list)
se = {}
prods = groupby_of_all.index
for i, j in enumerate(groupby_of_all.values):
    list = []
    for k in j:
        x = nltk.word_tokenize(k)
        y = nltk.pos_tag(x)
        list.append(y)
    se[prods[i]] = list

# %%
ar = {}
aspect = []
sent = []



# for i, j in enumerate(se):
#             for k, l in enumerate(j):
#                 if l[1] == 'NN':
#                     aspect.append(l[0])
#                     sentences = ''
#                     for m in j[k:]:
#                         sentences += ' ' + m[0]
#                         if m[1] == 'JJ':
#                             break
#                     sent.append(sentences.strip())
#                     ar[l[0]] = sentences
#         return ar

# %%
#prods = list(se.keys())
clean_review = {}
aspects = []

for i, j in enumerate(se.values()):
    for k in j:
        for l, m in enumerate(k):
            if m[1] == 'NN':
                aspect = m[0]
                aspects.append(aspect)
                sent = ''
                for n in k[l:]:
                    sent += n[0] + ' '
                    if n[1] == 'JJ':
                        break
                if aspect in clean_review:
                    clean_review[aspect] = [sent]
                
        
    if i == 0:
        break

# %%
def sentiment(d):
    sid = SentimentIntensityAnalyzer()
    for i, j in d.items():
        #print(j)
        for k, l in j.items():
            d2 = {}
            for m in l:
                sentiment = sid.polarity_scores(m)
                d2[m] = sentiment
          
            d[i][k] = d2
    return d
            
x = sentiment(d)  


sent =['The camera is great and the memory is not good', 'The memory is good and camera not is great']
clean = []

prod = 'Iphone 14'

for k in sent:
    x = nltk.word_tokenize(k)
    y = nltk.pos_tag(x)
    clean.append(y)


asp = []
d = {}
d1 = {}
for i, j in enumerate(clean):
    
    for a, k in enumerate(j):
        
        if k[1] == 'NN':
            aspect = k[0]
            sentence = ''
            if aspect not in d1.keys():
                d1[aspect] = []
            for m in j[a:]:
                sentence += m[0] + ' '
                if m[1] == 'JJ':
                    break
            x = d1[aspect]
            x.append(sentence)
    d[prod] = d1
            
        #d[prod] = d1
d

# %%
d = se['APPLE iPhone 11 (Black, 128 GB)']
x = {}
x['APPLE iPhone 11 (Black, 128 GB)'] = d

# %%
products_review_with_sentiments = {}
for i, j in x.items():
    d1 = {}
    for k in j:
        for l, m in enumerate(k):
            if m[1] == 'NN':
                aspect = m[0]
                sentence = ''
                if aspect not in d1.keys():
                    d1[aspect] = []
                for n in k[l:]:
                    sentence += n[0] + ' '
                    if m[1] == 'JJ':
                        break
                x = d1[aspect]
                x.append(sentence.strip())
        products_review_with_sentiments[i] = d1

# %%
for i, j in products_review_with_sentiments.items():
    print(i)

# %%
def sentiment(d):
    sid = SentimentIntensityAnalyzer()
    for i, j in d.items():
        #print(j)
        for k, l in j.items():
            d2 = {}
            for m in l:
                sentiment = sid.polarity_scores(m)
                d2[m] = sentiment
          
            d[i][k] = d2
    return d
            
x = sentiment(products_review_with_sentiments)

# %%
for i in x.keys():
    key = x[i].keys()
    for j in key:
        s_key = x[i][j].values()
        for k in s_key:
            print(k)

# %%
# one done


compound_aspect = {}
for i in x.keys():
    asp = x[i]
    pos = 0
    neg = 0
    neu = 0 
    compound = 0
    count = 0
    for j in asp.keys():
        comment = x[i][j]
        for k in comment.values():
            pos += k['pos']
            neg += k['neg']
            neu += k['neu']
            compound += k['compound']
            count+= 1
            
    compound_aspect[i] = compound/ count 
    
compound_aspect
# Out:
# {'APPLE iPhone 11 (Black, 128 GB)': 0.5941265624999996}

# %%
# all down lets wrap tomorrow

aspect_info = {}
for i in x.keys():
    asp = x[i]
    
    for j in asp.keys():
        pos = 0
        neg = 0
        neu = 0 
        compound = 0
        count = 0
        comment = x[i][j]
        for k in comment.values():
            pos += k['pos']
            neg += k['neg']
            neu += k['neu']
            compound += k['compound']
            count+= 1
        
        info = {'pos' : pos/ count, 'neg' : neg/ count, 'neu' : neu/ count, 'compound' : compound/ count}
            
        aspect_info[j] = info
aspect_info
# Out:
# {'iPhone': {'pos': 0.29242857142857137,
#   'neg': 0.019357142857142857,
#   'neu': 0.6882142857142858,
#   'compound': 0.600157142857143},
#  'price': {'pos': 0.3786,
#   'neg': 0.019200000000000002,
#   'neu': 0.6022000000000001,
#   'compound': 0.8711599999999999},
#  'camera': {'pos': 0.34326666666666666,
#   'neg': 0.020399999999999998,
#   'neu': 0.6363333333333333,
#   'compound': 0.6552133333333334},
#  'quality': {'pos': 0.246,
#   'neg': 0.02707692307692308,
#   'neu': 0.7269230769230769,
#   'compound': 0.6647230769230769},
#  'level': {'pos': 0.235,
#   'neg': 0.0515,
#   'neu': 0.713,
#   'compound': 0.7818499999999999},
#  'packaging': {'pos': 0.223,
#   'neg': 0.084,
#   'neu': 0.6925,
#   'compound': 0.23345000000000002},
#  'product': {'pos': 0.34442857142857136,
#   'neg': 0.012857142857142857,
#   'neu': 0.6427142857142857,
#   'compound': 0.5959571428571427},
#  'think': {'pos': 0.159, 'neg': 0.0, 'neu': 0.841, 'compound': 0.31845},
#  'decision': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  'battery': {'pos': 0.3499090909090909,
#   'neg': 0.004909090909090909,
#   'neu': 0.6451818181818182,
#   'compound': 0.6543363636363636},
#  'performance': {'pos': 0.3838571428571429,
#   'neg': 0.020857142857142855,
#   'neu': 0.5952857142857143,
#   'compound': 0.7633285714285714},
#  'experience': {'pos': 0.2102,
#   'neg': 0.0324,
#   'neu': 0.7575999999999999,
#   'compound': 0.46756000000000003},
#  'customer': {'pos': 0.484, 'neg': 0.088, 'neu': 0.428, 'compound': 0.9168},
#  'security': {'pos': 0.446, 'neg': 0.1, 'neu': 0.454, 'compound': 0.8654},
#  'recommend': {'pos': 0.27, 'neg': 0.186, 'neu': 0.544, 'compound': 0.1002},
#  'everyone': {'pos': 0.14, 'neg': 0.219, 'neu': 0.641, 'compound': -0.2755},
#  'delay': {'pos': 0.342, 'neg': 0.207, 'neu': 0.45, 'compound': 0.3612},
#  'thing': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  'delivery': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  'beast': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  'mobile': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  'generation': {'pos': 0.313, 'neg': 0.0, 'neu': 0.687, 'compound': 0.9541},
#  'model': {'pos': 0.366, 'neg': 0.0, 'neu': 0.634, 'compound': 0.9541},
#  'phone': {'pos': 0.35065384615384604,
#   'neg': 0.021384615384615387,
#   'neu': 0.6280000000000001,
#   'compound': 0.5872576923076923},
#  'angle': {'pos': 0.381, 'neg': 0.0, 'neu': 0.619, 'compound': 0.9265},
#  'something': {'pos': 0.392, 'neg': 0.0, 'neu': 0.608, 'compound': 0.9265},
#  'count': {'pos': 0.404, 'neg': 0.0, 'neu': 0.596, 'compound': 0.9265},
#  'device': {'pos': 0.18433333333333335,
#   'neg': 0.0,
#   'neu': 0.8156666666666667,
#   'compound': 0.32693333333333335},
#  'variant': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  
{'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  'stuck': {'pos': 0.077, 'neg': 0.053, 'neu': 0.871, 'compound': 0.2263},
#  'everything': {'pos': 0.094, 'neg': 0.0, 'neu': 0.906, 'compound': 0.4404},
#  'redMy': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  'iphone': {'pos': 0.178,
#   'neg': 0.0,
#   'neu': 0.8220000000000001,
#   'compound': 0.4371},
#  'aboutIm': {'pos': 0.399, 'neg': 0.0, 'neu': 0.601, 'compound': 0.8742},
#  'purchase': {'pos': 0.309, 'neg': 0.0, 'neu': 0.691, 'compound': 0.7408},
#  'budget': {'pos': 0.22, 'neg': 0.0, 'neu': 0.78, 'compound': 0.9136},
#  'explain': {'pos': 0.266, 'neg': 0.0, 'neu': 0.734, 'compound': 0.9136},
#  'range': {'pos': 0.32, 'neg': 0.0, 'neu': 0.68, 'compound': 0.9136},
#  'comparison': {'pos': 0.328, 'neg': 0.0, 'neu': 0.672, 'compound': 0.9136},
#  'youll': {'pos': 0.346, 'neg': 0.0, 'neu': 0.654, 'compound': 0.9136},
#  'video': {'pos': 0.286, 'neg': 0.0, 'neu': 0.714, 'compound': 0.7506},
#  'person': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  'channel': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  'improvement': {'pos': 0.429, 'neg': 0.0, 'neu': 0.571, 'compound': 0.4588},
#  'processor': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0},
#  'difference': {'pos': 0.234, 'neg': 0.055, 'neu': 0.711, 'compound': 0.8316},
#  'watch': {'pos': 0.244, 'neg': 0.057, 'neu': 0.699, 'compound': 0.8316},
#  'movie': {'pos': 0.249, 'neg': 0.058, 'neu': 0.693, 'compound': 0.8316},
#  'colours': {'pos': 0.266, 'neg': 0.062, 'neu': 0.671, 'compound': 0.8316},
#  'vibrant': {'pos': 0.273, 'neg': 0.064, 'neu': 0.664, 'compound': 0.8316},
#  'charger': {'pos': 0.27, 'neg': 0.09, 'neu': 0.6395, 'compound': 0.6597},
#  'watts': {'pos': 0.24, 'neg': 0.08, 'neu': 0.68, 'compound': 0.6597},
#  'charge': {'pos': 0.263, 'neg': 0.088, 'neu': 0.649, 'compound': 0.6597},
#  'promise': {'pos': 0.431, 'neg': 0.144, 'neu': 0.426, 'compound': 0.6597},
#  'world': {'pos': 0.635, 'neg': 0.0, 'neu': 0.365, 'compound': 0.9396},
#  'bright': {'pos': 0.645, 'neg': 0.0, 'neu': 0.355, 'compound': 0.9141},
#  'regret': {'pos': 0.35, 'neg': 0.233, 'neu': 0.417, 'compound': 0.34},
#  'switch': {'pos': 0.0, 'neg': 0.0, 'neu': 1.0, 'compound': 0.0}}

# %%
groupby_of_all = df.groupby('Product')['Cleaned'].apply(list)
for i in groupby_of_all:
    print(i.values)

# %%
# df = pd.read_csv('Iphone14Reviews.csv')

# df.drop('Cleaned', axis = 1)


# x = Cleancsv(df)
# df = x.clean(df)

# p, pol, l, pr, ra = x.predict(df)






groupby_of_all = df.groupby('Product')['Cleaned1'].apply(list)
se = {}
prods = groupby_of_all.index
for i, j in enumerate(groupby_of_all.values):
    list = []
    for k in j:
        x = nltk.word_tokenize(k)
        y = nltk.pos_tag(x)
        list.append(y)
    se[prods[i]] = list
    

    
d = se['APPLE iPhone 11 (Black, 128 GB)']
x = {}
x['APPLE iPhone 11 (Black, 128 GB)'] = d


products_review_with_sentiments = {}
for i, j in x.items():
    d1 = {}
    for k in j:
        for l, m in enumerate(k):
            if len(m[0]) > 4 and '...' not in m[0] and '....':
                if m[1] == 'NN' or m[1] == 'VB':
                    aspect = m[0]
                    sentence = ''
                    if aspect not in d1.keys():
                        d1[aspect] = []
                    for n in k[l:]:
                        sentence += n[0] + ' '
                        if m[1] == 'JJ':
                            break
                    x = d1[aspect]
                    x.append(sentence.strip())
        products_review_with_sentiments[i] = d1

def sentiment(d):
    sid = SentimentIntensityAnalyzer()
    for i, j in d.items():
        #print(j)
        for k, l in j.items():
            d2 = {}
            for m in l:
                sentiment = sid.polarity_scores(m)
                d2[m] = sentiment
          
            d[i][k] = d2
    return d
            
x = sentiment(products_review_with_sentiments)


compound_aspect = {}
for i in x.keys():
    asp = x[i]
    pos = 0
    neg = 0
    neu = 0 
    compound = 0
    count = 0
    for j in asp.keys():
        comment = x[i][j]
        for k in comment.values():
            pos += k['pos']
            neg += k['neg']
            neu += k['neu']
            compound += k['compound']
            count+= 1
            
    compound_aspect[i] = compound/ count 
   
aspect_info = {}
for i in x.keys():
    asp = x[i]
    
    for j in asp.keys():
        pos = 0
        neg = 0
        neu = 0 
        compound = 0
        count = 0
        comment = x[i][j]
        for k in comment.values():
            pos += k['pos']
            neg += k['neg']
            neu += k['neu']
            compound += k['compound']
            count+= 1
        
        info = {'pos' : pos/ count, 'neg' : neg/ count, 'neu' : neu/ count, 'compound' : compound/ count}
            
        aspect_info[j] = info
aspect_info
# Out:
# {'APPLE iPhone 11 (Black, 128 GB)': {'iPhone': {'iPhone bought reasonable price camera quality next level awesome n superior quality android phones even closeRIP also battery really good packaging Flipkart iPhone poor expensive product firstly im bit worried quality product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.091,
#     'neu': 0.652,
#     'pos': 0.257,
#     'compound': 0.8932},
#    'iPhone poor expensive product firstly im bit worried quality product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.18,
#     'neu': 0.678,
#     'pos': 0.142,
#     'compound': -0.0258},
#    'iPhone snappy experience apple kind Upgraded iPhone ProsCamera top class Battery top performed Chipset need say apple kind Security expect apple Display super bright industry leading colour accuracy super responsive Build quality expect apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.567,
#     'pos': 0.433,
#     'compound': 0.9836},
#    'iPhone ProsCamera top class Battery top performed Chipset need say apple kind Security expect apple Display super bright industry leading colour accuracy super responsive Build quality expect apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.563,
#     'pos': 0.437,
#     'compound': 0.9792},
#    'iPhone premium standard level phone maybe could find brands valu like iPhone thinking buy iPhone dont think much grab bro iPhone owner give feeling like owning Lamborghini pocket According middle class family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 0.835,
#     'pos': 0.165,
#     'compound': 0.6705},
#    'iPhone thinking buy iPhone dont think much grab bro iPhone owner give feeling like owning Lamborghini pocket According middle class family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 0.852,
#     'pos': 0.148,
#     'compound': 0.4588},
#    'iPhone owner give feeling like owning Lamborghini pocket According middle class family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 0.778,
#     'pos': 0.222,
#     'compound': 0.4588},
#    'iPhone loved one': {'neg': 0.0,
#     'neu': 0.339,
#     'pos': 0.661,
#     'compound': 0.5994},
#    'iPhone love': {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.6369},
#    'iPhone shifted android Samsung Note series iPhone strong build quality peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.793,
#     'pos': 0.207,
#     'compound': 0.7783},
#    'iPhone strong build quality peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.746,
#     'pos': 0.254,
#     'compound': 0.7783},
#    'iPhone seen specs everything good except display somewhere even amoled LCD display decided go iPhone never used IOS device android user past years ordered IPhone gb product redMy experience using weeks delivery': {'neg': 0.0,
#     'neu': 0.914,
#     'pos': 0.086,
#     'compound': 0.4404},
#    'iPhone never used IOS device android user past years ordered IPhone gb product redMy experience using weeks delivery': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.726,
#     'pos': 0.274,
#     'compound': 0.7506}},
#   'price': {'price camera quality next level awesome n superior quality android phones even closeRIP also battery really good packaging Flipkart iPhone poor expensive product firstly im bit worried quality product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.096,
#     'neu': 0.633,
#     'pos': 0.271,
#     'compound': 0.8932},
#    'price Apple days review Battery enough day even Internet mostly internet usageCamera awesome cool android MP equal MPA Bionic chip give high performance without hanging Audio stereo speakers give Dolby atoms sound crystal clearVideo recording like cinematic shots every sec K fps awesome phone iPhone loved one': {'neg': 0.0,
#     'neu': 0.708,
#     'pos': 0.292,
#     'compound': 0.9509},
#    'price images clicked iPhone love': {'neg': 0.0,
#     'neu': 0.488,
#     'pos': 0.512,
#     'compound': 0.6369},
#    'price segmentIf survive HD LCD panel thicker bezels notch top good phone youCameras awesome battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.494,
#     'pos': 0.506,
#     'compound': 0.9612},
#    'price range comparison camera youll love picture quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.688,
#     'pos': 0.312,
#     'compound': 0.9136}},
#   'camera': {'camera quality next level awesome n superior quality android phones even closeRIP also battery really good packaging Flipkart iPhone poor expensive product firstly im bit worried quality product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.098,
#     'neu': 0.626,
#     'pos': 0.276,
#     'compound': 0.8932},
#    'camera quality expected battery also good performance Display body touch experience best Ive ever Sound quality speakers sufficient Apple known customer friendly security services see processor best work would definitely recommend everyone looking go without delay amazing thing delivery Flipkart delivered span': {'neg': 0.051,
#     'neu': 0.549,
#     'pos': 0.4,
#     'compound': 0.9638},
#    'camera like dslr battery good think beast mobile': {'neg': 0.0,
#     'neu': 0.526,
#     'pos': 0.474,
#     'compound': 0.6597},
#    'camera like fantabulous sound crystal clear red color damn attractive loving Must buy love photography Lucky get sale thank Flipkart': {'neg': 0.075,
#     'neu': 0.332,
#     'pos': 0.593,
#     'compound': 0.9565},
#    'camera': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#    'camera addictive IOS lover phone best choice': {'neg': 0.0,
#     'neu': 0.385,
#     'pos': 0.615,
#     'compound': 0.8402},
#    'camera touch feeling worth buying mobile': {'neg': 0.0,
#     'neu': 0.541,
#     'pos': 0.459,
#     'compound': 0.34},
#    'camera awesome feel iPhone awesome Good gaming also try pubg hd wow': {'neg': 0.0,
#     'neu': 0.349,
#     'pos': 0.651,
#     'compound': 0.9423},
#    'camera videography Soun': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'camera picture quality Amazing face id unlocked dark room Strong battery perfect screen size carry easily pocket third iPhone shifted android Samsung Note series iPhone strong build quality peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.667,
#     'pos': 0.333,
#     'compound': 0.9638},
#    'camera battery backup display bionic chipThat s review phone differ': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'camera youll love picture quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.663,
#     'pos': 0.337,
#     'compound': 0.9136},
#    'camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.686,
#     'pos': 0.314,
#     'compound': 0.7506},
#    'camera Display touching Nice Smooth improvement phone new processor fast': {'neg': 0.0,
#     'neu': 0.58,
#     'pos': 0.42,
#     'compound': 0.7003},
#    'camera good performance lag lcd display also good difference come watch movie prime Netflix colours vibrant see amoled display charger box watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.082,
#     'neu': 0.641,
#     'pos': 0.277,
#     'compound': 0.9042}},
#   'quality': {'quality next level awesome n superior quality android phones even closeRIP also battery really good packaging Flipkart iPhone poor expensive product firstly im bit worried quality product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.099,
#     'neu': 0.619,
#     'pos': 0.281,
#     'compound': 0.8932},
#    'quality android phones even closeRIP also battery really good packaging Flipkart iPhone poor expensive product firstly im bit worried quality product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.124,
#     'neu': 0.703,
#     'pos': 0.173,
#     'compound': 0.4754},
#    'quality product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.0,
#     'neu': 0.769,
#     'pos': 0.231,
#     'compound': 0.6369},
#    'quality expected battery also good performance Display body touch experience best Ive ever Sound quality speakers sufficient Apple known customer friendly security services see processor best work would definitely recommend everyone looking go without delay amazing thing delivery Flipkart delivered span': {'neg': 0.052,
#     'neu': 0.541,
#     'pos': 0.407,
#     'compound': 0.9638},
#    'quality speakers sufficient Apple known customer friendly security services see processor best work would definitely recommend everyone looking go without delay amazing thing delivery Flipkart delivered span': {'neg': 0.077,
#     'neu': 0.5,
#     'pos': 0.424,
#     'compound': 0.9168},
#    'quality amazing wide angle something count upon Performance wise amazing feels premium holding hand big YES device Go GB variant K videos occupy lots space storage get quickly Try buy': {'neg': 0.0,
#     'neu': 0.581,
#     'pos': 0.419,
#     'compound': 0.9541},
#    'quality expect apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.766,
#     'pos': 0.234,
#     'compound': 0.7269},
#    'quality': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#    'quality photography lot task': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'quality Amazing face id unlocked dark room Strong battery perfect screen size carry easily pocket third iPhone shifted android Samsung Note series iPhone strong build quality peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.655,
#     'pos': 0.345,
#     'compound': 0.9638},
#    'quality peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.837,
#     'pos': 0.163,
#     'compound': 0.5423},
#    'quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.721,
#     'pos': 0.279,
#     'compound': 0.8176},
#    'quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.758,
#     'pos': 0.242,
#     'compound': 0.7506}},
#   'level': {'level awesome n superior quality android phones even closeRIP also battery really good packaging Flipkart iPhone poor expensive product firstly im bit worried quality product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.103,
#     'neu': 0.604,
#     'pos': 0.292,
#     'compound': 0.8932},
#    'level phone maybe could find brands valu like iPhone thinking buy iPhone dont think much grab bro iPhone owner give feeling like owning Lamborghini pocket According middle class family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 0.822,
#     'pos': 0.178,
#     'compound': 0.6705}},
#   'packaging': {'packaging Flipkart iPhone poor expensive product firstly im bit worried quality product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.168,
#     'neu': 0.698,
#     'pos': 0.133,
#     'compound': -0.0258},
#    'packaging also really good ur planning buy go': {'neg': 0.0,
#     'neu': 0.687,
#     'pos': 0.313,
#     'compound': 0.4927}},
#   'product': {'product firstly im bit worried quality product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.09,
#     'neu': 0.738,
#     'pos': 0.172,
#     'compound': 0.4588},
#    'product purchased online product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.0,
#     'neu': 0.756,
#     'pos': 0.244,
#     'compound': 0.6369},
#    'product think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.0,
#     'neu': 0.704,
#     'pos': 0.296,
#     'compound': 0.6369},
#    'product phone looks premium battary also good expected Wide angle camera addictive IOS lover phone best choice': {'neg': 0.0,
#     'neu': 0.562,
#     'pos': 0.438,
#     'compound': 0.8979},
#    'product Thank u flipkart received item time loved': {'neg': 0.0,
#     'neu': 0.439,
#     'pos': 0.561,
#     'compound': 0.7506},
#    'product redMy experience using weeks delivery': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'product much satisfied love phone': {'neg': 0.0,
#     'neu': 0.3,
#     'pos': 0.7,
#     'compound': 0.7906}},
#   'think': {'think mine best decision bought Flipkart online got genuine Apple': {'neg': 0.0,
#     'neu': 0.682,
#     'pos': 0.318,
#     'compound': 0.6369},
#    'think beast mobile': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'decision': {'decision bought Flipkart online got genuine Apple': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'battery': {'battery also good performance Display body touch experience best Ive ever Sound quality speakers sufficient Apple known customer friendly security services see processor best work would definitely recommend everyone looking go without delay amazing thing delivery Flipkart delivered span': {'neg': 0.054,
#     'neu': 0.525,
#     'pos': 0.421,
#     'compound': 0.9638},
#    'battery good think beast mobile': {'neg': 0.0,
#     'neu': 0.58,
#     'pos': 0.42,
#     'compound': 0.4404},
#    'battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.631,
#     'pos': 0.369,
#     'compound': 0.6249},
#    'battery gives best performance love camera': {'neg': 0.0,
#     'neu': 0.323,
#     'pos': 0.677,
#     'compound': 0.8555},
#    'battery issue thought upgrade Really like mobile Internal storage compare camera touch feeling worth buying mobile': {'neg': 0.0,
#     'neu': 0.677,
#     'pos': 0.323,
#     'compound': 0.6361},
#    'battery backup nice continuously hours use itcamera awesome display fabi love alot wait days pre ordered overalll s worth price images clicked iPhone love': {'neg': 0.0,
#     'neu': 0.511,
#     'pos': 0.489,
#     'compound': 0.9531},
#    'battery perfect screen size carry easily pocket third iPhone shifted android Samsung Note series iPhone strong build quality peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.713,
#     'pos': 0.287,
#     'compound': 0.9169},
#    'battery backup display bionic chipThat s review phone differ': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.428,
#     'pos': 0.572,
#     'compound': 0.8934},
#    'battery performance Camera price range comparison camera youll love picture quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.709,
#     'pos': 0.291,
#     'compound': 0.9136},
#    'battery ba': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   'performance': {'performance Display body touch experience best Ive ever Sound quality speakers sufficient Apple known customer friendly security services see processor best work would definitely recommend everyone looking go without delay amazing thing delivery Flipkart delivered span': {'neg': 0.059,
#     'neu': 0.536,
#     'pos': 0.405,
#     'compound': 0.9523},
#    'performance unbeaten camera like dslr battery good think beast mobile': {'neg': 0.0,
#     'neu': 0.597,
#     'pos': 0.403,
#     'compound': 0.6597},
#    'performance love camera': {'neg': 0.0,
#     'neu': 0.323,
#     'pos': 0.677,
#     'compound': 0.6369},
#    'performance without hanging Audio stereo speakers give Dolby atoms sound crystal clearVideo recording like cinematic shots every sec K fps awesome phone iPhone loved one': {'neg': 0.0,
#     'neu': 0.667,
#     'pos': 0.333,
#     'compound': 0.8885},
#    'performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.674,
#     'pos': 0.326,
#     'compound': 0.4404},
#    'performance Camera price range comparison camera youll love picture quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.703,
#     'pos': 0.297,
#     'compound': 0.9136},
#    'performance lag lcd display also good difference come watch movie prime Netflix colours vibrant see amoled display charger box watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.087,
#     'neu': 0.667,
#     'pos': 0.246,
#     'compound': 0.8519}},
#   'experience': {'experience best Ive ever Sound quality speakers sufficient Apple known customer friendly security services see processor best work would definitely recommend everyone looking go without delay amazing thing delivery Flipkart delivered span': {'neg': 0.064,
#     'neu': 0.498,
#     'pos': 0.439,
#     'compound': 0.9523},
#    'experience apple kind Upgraded iPhone ProsCamera top class Battery top performed Chipset need say apple kind Security expect apple Display super bright industry leading colour accuracy super responsive Build quality expect apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.555,
#     'pos': 0.445,
#     'compound': 0.9836},
#    'experience coming back iOS nearly decade versatile android though phone sturdy dropped accidentally couple times nothing happened fortunately camera awesome': {'neg': 0.098,
#     'neu': 0.735,
#     'pos': 0.167,
#     'compound': 0.4019},
#    'experience using weeks delivery': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'experience Anyone whos thinking buying would simply say go without second thoughts': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'customer': {'customer friendly security services see processor best work would definitely recommend everyone looking go without delay amazing thing delivery Flipkart delivered span': {'neg': 0.088,
#     'neu': 0.428,
#     'pos': 0.484,
#     'compound': 0.9168}},
#   'security': {'security services see processor best work would definitely recommend everyone looking go without delay amazing thing delivery Flipkart delivered span': {'neg': 0.1,
#     'neu': 0.454,
#     'pos': 0.446,
#     'compound': 0.8654}},
#   'recommend': {'recommend everyone looking go without delay amazing thing delivery Flipkart delivered span': {'neg': 0.186,
#     'neu': 0.544,
#     'pos': 0.27,
#     'compound': 0.1002}},
#   'everyone': {'everyone looking go without delay amazing thing delivery Flipkart delivered span': {'neg': 0.219,
#     'neu': 0.641,
#     'pos': 0.14,
#     'compound': -0.2755}},
#   'delay': {'delay amazing thing delivery Flipkart delivered span': {'neg': 0.207,
#     'neu': 0.45,
#     'pos': 0.342,
#     'compound': 0.3612}},
#   'thing': {'thing delivery Flipkart delivered span': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'delivery': {'delivery Flipkart delivered span': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'delivery': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   'beast': {'beast mobile': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'mobile': {'mobile': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   'generation': {'generation iPhones using XR still hold sometime upgrade model else phone must buy Camera quality amazing wide angle something count upon Performance wise amazing feels premium holding hand big YES device Go GB variant K videos occupy lots space storage get quickly Try buy': {'neg': 0.0,
#     'neu': 0.687,
#     'pos': 0.313,
#     'compound': 0.9541}},
#   'model': {'model else phone must buy Camera quality amazing wide angle something count upon Performance wise amazing feels premium holding hand big YES device Go GB variant K videos occupy lots space storage get quickly Try buy': {'neg': 0.0,
#     'neu': 0.634,
#     'pos': 0.366,
#     'compound': 0.9541}},
#   'phone': {'phone must buy Camera quality amazing wide angle something count upon Performance wise amazing feels premium holding hand big YES device Go GB variant K videos occupy lots space storage get quickly Try buy': {'neg': 0.0,
#     'neu': 0.618,
#     'pos': 0.382,
#     'compound': 0.9541},
#    'phone great cameras better battery gives best performance love camera': {'neg': 0.0,
#     'neu': 0.28,
#     'pos': 0.72,
#     'compound': 0.9468},
#    'phone looks premium battary also good expected Wide angle camera addictive IOS lover phone best choice': {'neg': 0.0,
#     'neu': 0.544,
#     'pos': 0.456,
#     'compound': 0.8979},
#    'phone best choice': {'neg': 0.0,
#     'neu': 0.323,
#     'pos': 0.677,
#     'compound': 0.6369},
#    'phone sturdy dropped accidentally couple times nothing happened fortunately camera awesome': {'neg': 0.155,
#     'neu': 0.581,
#     'pos': 0.265,
#     'compound': 0.4019},
#    'phone maybe could find brands valu like iPhone thinking buy iPhone dont think much grab bro iPhone owner give feeling like owning Lamborghini pocket According middle class family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 0.817,
#     'pos': 0.183,
#     'compound': 0.6705},
#    'phone iPhone loved one': {'neg': 0.0,
#     'neu': 0.435,
#     'pos': 0.565,
#     'compound': 0.5994},
#    'phone loving upgradation love color love assebility phone need learn functionality far seen s quite easy lot functions work specially content writer blogger get lot content creation platforms really amazing phone good quality photography lot task': {'neg': 0.0,
#     'neu': 0.53,
#     'pos': 0.47,
#     'compound': 0.9773},
#    'phone need learn functionality far seen s quite easy lot functions work specially content writer blogger get lot content creation platforms really amazing phone good quality photography lot task': {'neg': 0.0,
#     'neu': 0.657,
#     'pos': 0.343,
#     'compound': 0.9109},
#    'phone good quality photography lot task': {'neg': 0.0,
#     'neu': 0.633,
#     'pos': 0.367,
#     'compound': 0.4404},
#    'phone used everSo go want phone best specification like camera battery backup display bionic chipThat s review phone differ': {'neg': 0.0,
#     'neu': 0.652,
#     'pos': 0.348,
#     'compound': 0.7906},
#    'phone best specification like camera battery backup display bionic chipThat s review phone differ': {'neg': 0.0,
#     'neu': 0.621,
#     'pos': 0.379,
#     'compound': 0.7717},
#    'phone differ': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#    'phone buy compromise display display device pretty good get options better displays price segmentIf survive HD LCD panel thicker bezels notch top good phone youCameras awesome battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.496,
#     'pos': 0.504,
#     'compound': 0.9808},
#    'phone youCameras awesome battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.403,
#     'pos': 0.597,
#     'compound': 0.9413},
#    'phone decided upgrade stuck Samsung plus iPhone seen specs everything good except display somewhere even amoled LCD display decided go iPhone never used IOS device android user past years ordered IPhone gb product redMy experience using weeks delivery': {'neg': 0.049,
#     'neu': 0.88,
#     'pos': 0.071,
#     'compound': 0.2263},
#    'phone happy product much satisfied love phone': {'neg': 0.0,
#     'neu': 0.272,
#     'pos': 0.728,
#     'compound': 0.8934},
#    'phone': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#    'phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.652,
#     'pos': 0.348,
#     'compound': 0.7506},
#    'phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.769,
#     'pos': 0.231,
#     'compound': 0.4019},
#    'phone ever': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#    'phone new processor fast': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.136,
#     'neu': 0.455,
#     'pos': 0.409,
#     'compound': 0.6597},
#    'phone damn good close eyes buy thanks': {'neg': 0.216,
#     'neu': 0.32,
#     'pos': 0.464,
#     'compound': 0.4767},
#    'phone world Display good bright Trust freinds r never regret Buying go love phone switch iphone x': {'neg': 0.0,
#     'neu': 0.39,
#     'pos': 0.61,
#     'compound': 0.9396},
#    'phone switch iphone x': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'angle': {'angle something count upon Performance wise amazing feels premium holding hand big YES device Go GB variant K videos occupy lots space storage get quickly Try buy': {'neg': 0.0,
#     'neu': 0.619,
#     'pos': 0.381,
#     'compound': 0.9265}},
#   'something': {'something count upon Performance wise amazing feels premium holding hand big YES device Go GB variant K videos occupy lots space storage get quickly Try buy': {'neg': 0.0,
#     'neu': 0.608,
#     'pos': 0.392,
#     'compound': 0.9265}},
#   'count': {'count upon Performance wise amazing feels premium holding hand big YES device Go GB variant K videos occupy lots space storage get quickly Try buy': {'neg': 0.0,
#     'neu': 0.596,
#     'pos': 0.404,
#     'compound': 0.9265}},
#   'device': {'device Go GB variant K videos occupy lots space storage get quickly Try buy': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'device pretty good get options better displays price segmentIf survive HD LCD panel thicker bezels notch top good phone youCameras awesome battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.447,
#     'pos': 0.553,
#     'compound': 0.9808},
#    'device android user past years ordered IPhone gb product redMy experience using weeks delivery': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'variant': {'variant K videos occupy lots space storage get quickly Try buy': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'space': {'space storage get quickly Try buy': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'storage': {'storage get quickly Try buy': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'storage compare camera touch feeling worth buying mobile': {'neg': 0.0,
#     'neu': 0.638,
#     'pos': 0.362,
#     'compound': 0.34}},
#   'apple': {'apple kind Upgraded iPhone ProsCamera top class Battery top performed Chipset need say apple kind Security expect apple Display super bright industry leading colour accuracy super responsive Build quality expect apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.549,
#     'pos': 0.451,
#     'compound': 0.9836},
#    'apple kind Security expect apple Display super bright industry leading colour accuracy super responsive Build quality expect apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.536,
#     'pos': 0.464,
#     'compound': 0.9753},
#    'apple Display super bright industry leading colour accuracy super responsive Build quality expect apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.583,
#     'pos': 0.417,
#     'compound': 0.9601},
#    'apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.747,
#     'pos': 0.253,
#     'compound': 0.7269},
#    'apple stic': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   'class': {'class Battery top performed Chipset need say apple kind Security expect apple Display super bright industry leading colour accuracy super responsive Build quality expect apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.565,
#     'pos': 0.435,
#     'compound': 0.9774},
#    'class family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'industry': {'industry leading colour accuracy super responsive Build quality expect apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.667,
#     'pos': 0.333,
#     'compound': 0.91},
#    'industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'accuracy': {'accuracy super responsive Build quality expect apple sturdy premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.638,
#     'pos': 0.362,
#     'compound': 0.91}},
#   'premium': {'premium durable beautiful stylish Os stable os smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 0.724,
#     'pos': 0.276,
#     'compound': 0.7269}},
#   'smartphone': {'smartphone industry Cons GDisplay based OLED technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.709,
#     'pos': 0.291,
#     'compound': 0.6249}},
#   'technology': {'technology Charger headphones apple stic': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'money': {'money star rating Excellent cameraBattery backup full day single chargeTougher water resistant design glossy backThe screen excellent brightness contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.665,
#     'pos': 0.335,
#     'compound': 0.9337},
#    'money love best phone ever': {'neg': 0.0,
#     'neu': 0.263,
#     'pos': 0.737,
#     'compound': 0.8555}},
#   'rating': {'rating Excellent cameraBattery backup full day single chargeTougher water resistant design glossy backThe screen excellent brightness contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.648,
#     'pos': 0.352,
#     'compound': 0.9337}},
#   'cameraBattery': {'cameraBattery backup full day single chargeTougher water resistant design glossy backThe screen excellent brightness contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.706,
#     'pos': 0.294,
#     'compound': 0.886}},
#   'backup': {'backup full day single chargeTougher water resistant design glossy backThe screen excellent brightness contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.698,
#     'pos': 0.302,
#     'compound': 0.886},
#    'backup nice continuously hours use itcamera awesome display fabi love alot wait days pre ordered overalll s worth price images clicked iPhone love': {'neg': 0.0,
#     'neu': 0.497,
#     'pos': 0.503,
#     'compound': 0.9531},
#    'backup display bionic chipThat s review phone differ': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.395,
#     'pos': 0.605,
#     'compound': 0.8934}},
#   'chargeTougher': {'chargeTougher water resistant design glossy backThe screen excellent brightness contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.658,
#     'pos': 0.342,
#     'compound': 0.886}},
#   'water': {'water resistant design glossy backThe screen excellent brightness contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.646,
#     'pos': 0.354,
#     'compound': 0.886}},
#   'design': {'design glossy backThe screen excellent brightness contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.62,
#     'pos': 0.38,
#     'compound': 0.886}},
#   'backThe': {'backThe screen excellent brightness contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.591,
#     'pos': 0.409,
#     'compound': 0.886}},
#   'screen': {'screen excellent brightness contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.574,
#     'pos': 0.426,
#     'compound': 0.886},
#    'screen size carry easily pocket third iPhone shifted android Samsung Note series iPhone strong build quality peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.771,
#     'pos': 0.229,
#     'compound': 0.8481}},
#   'brightness': {'brightness contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.66,
#     'pos': 0.34,
#     'compound': 0.7717}},
#   'contrastApple': {'contrastApple Bionic fastest smartphone chip planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.76,
#     'pos': 0.24,
#     'compound': 0.6249}},
#   'planetExcellent': {'planetExcellent battery life fast charging supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.661,
#     'pos': 0.339,
#     'compound': 0.6249}},
#   'supportStereo': {'supportStereo speakers great quality': {'neg': 0.0,
#     'neu': 0.423,
#     'pos': 0.577,
#     'compound': 0.6249}},
#   'butter': {'butter camera like fantabulous sound crystal clear red color damn attractive loving Must buy love photography Lucky get sale thank Flipkart': {'neg': 0.073,
#     'neu': 0.35,
#     'pos': 0.577,
#     'compound': 0.9565}},
#   'color': {'color damn attractive loving Must buy love photography Lucky get sale thank Flipkart': {'neg': 0.104,
#     'neu': 0.269,
#     'pos': 0.627,
#     'compound': 0.9274},
#    'color love assebility phone need learn functionality far seen s quite easy lot functions work specially content writer blogger get lot content creation platforms really amazing phone good quality photography lot task': {'neg': 0.0,
#     'neu': 0.608,
#     'pos': 0.392,
#     'compound': 0.9497}},
#   'loving': {'loving Must buy love photography Lucky get sale thank Flipkart': {'neg': 0.0,
#     'neu': 0.309,
#     'pos': 0.691,
#     'compound': 0.9246}},
#   'photography': {'photography Lucky get sale thank Flipkart': {'neg': 0.0,
#     'neu': 0.43,
#     'pos': 0.57,
#     'compound': 0.6486},
#    'photography lot task': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'thank': {'thank Flipkart': {'neg': 0.0,
#     'neu': 0.286,
#     'pos': 0.714,
#     'compound': 0.3612}},
#   'battary': {'battary also good expected Wide angle camera addictive IOS lover phone best choice': {'neg': 0.0,
#     'neu': 0.478,
#     'pos': 0.522,
#     'compound': 0.8979}},
#   'lover': {'lover phone best choice': {'neg': 0.0,
#     'neu': 0.2,
#     'pos': 0.8,
#     'compound': 0.8402}},
#   'choice': {'choice': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   'interface': {'interface mobile getting battery issue thought upgrade Really like mobile Internal storage compare camera touch feeling worth buying mobile': {'neg': 0.0,
#     'neu': 0.721,
#     'pos': 0.279,
#     'compound': 0.6361}},
#   'issue': {'issue thought upgrade Really like mobile Internal storage compare camera touch feeling worth buying mobile': {'neg': 0.0,
#     'neu': 0.66,
#     'pos': 0.34,
#     'compound': 0.6361}},
#   'compare': {'compare camera touch feeling worth buying mobile': {'neg': 0.0,
#     'neu': 0.595,
#     'pos': 0.405,
#     'compound': 0.34}},
#   'feeling': {'feeling worth buying mobile': {'neg': 0.0,
#     'neu': 0.37,
#     'pos': 0.63,
#     'compound': 0.34}},
#   'buying': {'buying mobile': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'gaming': {'gaming also try pubg hd wow': {'neg': 0.0,
#     'neu': 0.568,
#     'pos': 0.432,
#     'compound': 0.5859}},
#   'decade': {'decade versatile android though phone sturdy dropped accidentally couple times nothing happened fortunately camera awesome': {'neg': 0.123,
#     'neu': 0.667,
#     'pos': 0.21,
#     'compound': 0.4019}},
#   'sturdy': {'sturdy dropped accidentally couple times nothing happened fortunately camera awesome': {'neg': 0.166,
#     'neu': 0.552,
#     'pos': 0.283,
#     'compound': 0.4019}},
#   'nothing': {'nothing happened fortunately camera awesome': {'neg': 0.0,
#     'neu': 0.494,
#     'pos': 0.506,
#     'compound': 0.6249}},
#   'awesome': {'awesome': {'neg': 0.0,
#     'neu': 0.0,
#     'pos': 1.0,
#     'compound': 0.6249}},
#   'income': {'income first iPhone it like dream finally achieved chose iPhone premium standard level phone maybe could find brands valu like iPhone thinking buy iPhone dont think much grab bro iPhone owner give feeling like owning Lamborghini pocket According middle class family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 0.784,
#     'pos': 0.216,
#     'compound': 0.8402}},
#   'dream': {'dream finally achieved chose iPhone premium standard level phone maybe could find brands valu like iPhone thinking buy iPhone dont think much grab bro iPhone owner give feeling like owning Lamborghini pocket According middle class family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 0.809,
#     'pos': 0.191,
#     'compound': 0.7579},
#    'dream owning iphone since known aboutIm happy purchase totally worth Amazing experience Anyone whos thinking buying would simply say go without second thoughts': {'neg': 0.0,
#     'neu': 0.613,
#     'pos': 0.387,
#     'compound': 0.8995}},
#   'owner': {'owner give feeling like owning Lamborghini pocket According middle class family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 0.765,
#     'pos': 0.235,
#     'compound': 0.4588}},
#   'pocket': {'pocket According middle class family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'family': {'family boyBest camera videography Soun': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'videography': {'videography Soun': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'stereo': {'stereo speakers give Dolby atoms sound crystal clearVideo recording like cinematic shots every sec K fps awesome phone iPhone loved one': {'neg': 0.0,
#     'neu': 0.618,
#     'pos': 0.382,
#     'compound': 0.8885}},
#   'clearVideo': {'clearVideo recording like cinematic shots every sec K fps awesome phone iPhone loved one': {'neg': 0.0,
#     'neu': 0.488,
#     'pos': 0.512,
#     'compound': 0.8885}},
#   'display': {'display fabi love alot wait days pre ordered overalll s worth price images clicked iPhone love': {'neg': 0.0,
#     'neu': 0.538,
#     'pos': 0.462,
#     'compound': 0.8834},
#    'display bionic chipThat s review phone differ': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'display display device pretty good get options better displays price segmentIf survive HD LCD panel thicker bezels notch top good phone youCameras awesome battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.467,
#     'pos': 0.533,
#     'compound': 0.9808},
#    'display device pretty good get options better displays price segmentIf survive HD LCD panel thicker bezels notch top good phone youCameras awesome battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.457,
#     'pos': 0.543,
#     'compound': 0.9808},
#    'display somewhere even amoled LCD display decided go iPhone never used IOS device android user past years ordered IPhone gb product redMy experience using weeks delivery': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'display decided go iPhone never used IOS device android user past years ordered IPhone gb product redMy experience using weeks delivery': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0},
#    'display also good difference come watch movie prime Netflix colours vibrant see amoled display charger box watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.05,
#     'neu': 0.684,
#     'pos': 0.266,
#     'compound': 0.8934},
#    'display charger box watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.073,
#     'neu': 0.707,
#     'pos': 0.22,
#     'compound': 0.6597}},
#   'upgradation': {'upgradation love color love assebility phone need learn functionality far seen s quite easy lot functions work specially content writer blogger get lot content creation platforms really amazing phone good quality photography lot task': {'neg': 0.0,
#     'neu': 0.563,
#     'pos': 0.437,
#     'compound': 0.968}},
#   'assebility': {'assebility phone need learn functionality far seen s quite easy lot functions work specially content writer blogger get lot content creation platforms really amazing phone good quality photography lot task': {'neg': 0.0,
#     'neu': 0.666,
#     'pos': 0.334,
#     'compound': 0.9109}},
#   'functionality': {'functionality far seen s quite easy lot functions work specially content writer blogger get lot content creation platforms really amazing phone good quality photography lot task': {'neg': 0.0,
#     'neu': 0.626,
#     'pos': 0.374,
#     'compound': 0.9109}},
#   'writer': {'writer blogger get lot content creation platforms really amazing phone good quality photography lot task': {'neg': 0.0,
#     'neu': 0.562,
#     'pos': 0.438,
#     'compound': 0.854}},
#   'blogger': {'blogger get lot content creation platforms really amazing phone good quality photography lot task': {'neg': 0.0,
#     'neu': 0.54,
#     'pos': 0.46,
#     'compound': 0.854}},
#   'creation': {'creation platforms really amazing phone good quality photography lot task': {'neg': 0.0,
#     'neu': 0.428,
#     'pos': 0.572,
#     'compound': 0.854}},
#   'productDelivery': {'productDelivery fast well gift sister loved much': {'neg': 0.0,
#     'neu': 0.31,
#     'pos': 0.69,
#     'compound': 0.836}},
#   'sister': {'sister loved much': {'neg': 0.0,
#     'neu': 0.339,
#     'pos': 0.661,
#     'compound': 0.5994}},
#   'picture': {'picture quality Amazing face id unlocked dark room Strong battery perfect screen size carry easily pocket third iPhone shifted android Samsung Note series iPhone strong build quality peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.661,
#     'pos': 0.339,
#     'compound': 0.9638},
#    'picture quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.73,
#     'pos': 0.27,
#     'compound': 0.8176}},
#   'perfect': {'perfect screen size carry easily pocket third iPhone shifted android Samsung Note series iPhone strong build quality peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.706,
#     'pos': 0.294,
#     'compound': 0.9169}},
#   'series': {'series iPhone strong build quality peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.755,
#     'pos': 0.245,
#     'compound': 0.7783}},
#   'peace': {'peace mind next yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 0.829,
#     'pos': 0.171,
#     'compound': 0.5423}},
#   'yearsDont': {'yearsDont think much go suggest go minimum gb variant gb Ive attached puppy pics fi': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'specification': {'specification like camera battery backup display bionic chipThat s review phone differ': {'neg': 0.0,
#     'neu': 0.8,
#     'pos': 0.2,
#     'compound': 0.3612}},
#   'bionic': {'bionic chipThat s review phone differ': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'review': {'review phone differ': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'differ': {'differ': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   'compromise': {'compromise display display device pretty good get options better displays price segmentIf survive HD LCD panel thicker bezels notch top good phone youCameras awesome battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.477,
#     'pos': 0.523,
#     'compound': 0.9808}},
#   'segmentIf': {'segmentIf survive HD LCD panel thicker bezels notch top good phone youCameras awesome battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.48,
#     'pos': 0.52,
#     'compound': 0.9612}},
#   'panel': {'panel thicker bezels notch top good phone youCameras awesome battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.418,
#     'pos': 0.582,
#     'compound': 0.9612}},
#   'thicker': {'thicker bezels notch top good phone youCameras awesome battery backup excellent great performance decent premium look Good job Apple': {'neg': 0.0,
#     'neu': 0.4,
#     'pos': 0.6,
#     'compound': 0.9612}},
#   'planning': {'planning buy go': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'stuck': {'stuck Samsung plus iPhone seen specs everything good except display somewhere even amoled LCD display decided go iPhone never used IOS device android user past years ordered IPhone gb product redMy experience using weeks delivery': {'neg': 0.053,
#     'neu': 0.871,
#     'pos': 0.077,
#     'compound': 0.2263}},
#   'everything': {'everything good except display somewhere even amoled LCD display decided go iPhone never used IOS device android user past years ordered IPhone gb product redMy experience using weeks delivery': {'neg': 0.0,
#     'neu': 0.906,
#     'pos': 0.094,
#     'compound': 0.4404}},
#   'redMy': {'redMy experience using weeks delivery': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'iphone': {'iphone since known aboutIm happy purchase totally worth Amazing experience Anyone whos thinking buying would simply say go without second thoughts': {'neg': 0.0,
#     'neu': 0.644,
#     'pos': 0.356,
#     'compound': 0.8742},
#    'iphone x': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   'aboutIm': {'aboutIm happy purchase totally worth Amazing experience Anyone whos thinking buying would simply say go without second thoughts': {'neg': 0.0,
#     'neu': 0.601,
#     'pos': 0.399,
#     'compound': 0.8742}},
#   'purchase': {'purchase totally worth Amazing experience Anyone whos thinking buying would simply say go without second thoughts': {'neg': 0.0,
#     'neu': 0.691,
#     'pos': 0.309,
#     'compound': 0.7408}},
#   'budget': {'budget Iphone till date go guys without second thought Let explain guys Camera Display battery performance Camera price range comparison camera youll love picture quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.78,
#     'pos': 0.22,
#     'compound': 0.9136}},
#   'explain': {'explain guys Camera Display battery performance Camera price range comparison camera youll love picture quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.734,
#     'pos': 0.266,
#     'compound': 0.9136}},
#   'range': {'range comparison camera youll love picture quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.68,
#     'pos': 0.32,
#     'compound': 0.9136}},
#   'comparison': {'comparison camera youll love picture quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.672,
#     'pos': 0.328,
#     'compound': 0.9136}},
#   'youll': {'youll love picture quality well video quality Vlogger wanted iPhone k video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.654,
#     'pos': 0.346,
#     'compound': 0.9136}},
#   'video': {'video front camera got phone happy Battery use phone roughly active social media person youtube channel battery ba': {'neg': 0.0,
#     'neu': 0.714,
#     'pos': 0.286,
#     'compound': 0.7506}},
#   'person': {'person youtube channel battery ba': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'channel': {'channel battery ba': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'improvement': {'improvement phone new processor fast': {'neg': 0.0,
#     'neu': 0.571,
#     'pos': 0.429,
#     'compound': 0.4588}},
#   'processor': {'processor fast': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}},
#   'difference': {'difference come watch movie prime Netflix colours vibrant see amoled display charger box watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.055,
#     'neu': 0.711,
#     'pos': 0.234,
#     'compound': 0.8316}},
#   'watch': {'watch movie prime Netflix colours vibrant see amoled display charger box watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.057,
#     'neu': 0.699,
#     'pos': 0.244,
#     'compound': 0.8316}},
#   'movie': {'movie prime Netflix colours vibrant see amoled display charger box watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.058,
#     'neu': 0.693,
#     'pos': 0.249,
#     'compound': 0.8316}},
#   'colours': {'colours vibrant see amoled display charger box watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.062,
#     'neu': 0.671,
#     'pos': 0.266,
#     'compound': 0.8316}},
#   'vibrant': {'vibrant see amoled display charger box watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.064,
#     'neu': 0.664,
#     'pos': 0.273,
#     'compound': 0.8316}},
#   'charger': {'charger box watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.075,
#     'neu': 0.698,
#     'pos': 0.226,
#     'compound': 0.6597},
#    'charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.105,
#     'neu': 0.581,
#     'pos': 0.314,
#     'compound': 0.6597}},
#   'watts': {'watts takes hours charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.08,
#     'neu': 0.68,
#     'pos': 0.24,
#     'compound': 0.6597}},
#   'charge': {'charge guys prepare buy watts charger Finally android user first Iapple phone promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.088,
#     'neu': 0.649,
#     'pos': 0.263,
#     'compound': 0.6597}},
#   'promise': {'promise u guys iOS smooth overall phone damn good close eyes buy thanks': {'neg': 0.144,
#     'neu': 0.426,
#     'pos': 0.431,
#     'compound': 0.6597}},
#   'world': {'world Display good bright Trust freinds r never regret Buying go love phone switch iphone x': {'neg': 0.0,
#     'neu': 0.365,
#     'pos': 0.635,
#     'compound': 0.9396}},
#   'bright': {'bright Trust freinds r never regret Buying go love phone switch iphone x': {'neg': 0.0,
#     'neu': 0.355,
#     'pos': 0.645,
#     'compound': 0.9141}},
#   'regret': {'regret Buying go love phone switch iphone x': {'neg': 0.233,
#     'neu': 0.417,
#     'pos': 0.35,
#     'compound': 0.34}},
#   'switch': {'switch iphone x': {'neg': 0.0,
#     'neu': 1.0,
#     'pos': 0.0,
#     'compound': 0.0}}}}

# %%
for i,j in x.items():
    print(j.keys())
# Out:
# dict_keys(['iPhone', 'price', 'camera', 'quality', 'level', 'packaging', 'product', 'think', 'decision', 'battery', 'performance', 'experience', 'customer', 'security', 'recommend', 'everyone', 'delay', 'thing', 'delivery', 'beast', 'mobile', 'generation', 'model', 'phone', 'angle', 'something', 'count', 'device', 'variant', 'space', 'storage', 'apple', 'class', 'industry', 'accuracy', 'premium', 'smartphone', 'technology', 'money', 'rating', 'cameraBattery', 'backup', 'chargeTougher', 'water', 'design', 'backThe', 'screen', 'brightness', 'contrastApple', 'planetExcellent', 'supportStereo', 'butter', 'color', 'loving', 'photography', 'thank', 'battary', 'lover', 'choice', 'interface', 'issue', 'compare', 'feeling', 'buying', 'gaming', 'decade', 'sturdy', 'nothing', 'awesome', 'income', 'dream', 'owner', 'pocket', 'family', 'videography', 'stereo', 'clearVideo', 'display', 'upgradation', 'assebility', 'functionality', 'writer', 'blogger', 'creation', 'productDelivery', 'sister', 'picture', 'perfect', 'series', 'peace', 'yearsDont', 'specification', 'bionic', 'review', 'differ', 'compromise', 'segmentIf', 'panel', 'thicker', 'planning', 'stuck', 'everything', 'redMy', 'iphone', 'aboutIm', 'purchase', 'budget', 'explain', 'range', 'comparison', 'youll', 'video', 'person', 'channel', 'improvement', 'processor', 'difference', 'watch', 'movie', 'colours', 'vibrant', 'charger', 'watts', 'charge', 'promise', 'world', 'bright', 'regret', 'switch'])
